# %% [markdown]
# # Part two: LGBM, Random Forest and Neural Network - after dummy and hash-encoding

# %% [markdown]
# - after LGBM from the previous notebook, the new models will require us to get rid of the null values and to encode all the categorical features
# - in this notebook we will do that, re-run the LGBM to see if encoding changes results, and then we will proceed to run Random Forest and deep learning models

# %% [markdown]
# <a id = 'Content'><a/>
# ### Contents:
# - [1.0 Functions](#1.0)
# - [2.0 Null values](#2.0)
# - [3.0 Encoding](#3.0)
# - [4.0 Light GBM with dummy- and hash-encoding](#4.0)
#     - [4.1 light gbm 2 (encoded version)](#4.1)
#     - [4.2 light gbm w pos weights (encoded version)](#4.2)
#     - [4.3 same as 4.1 with pos weights](#4.3)
# - [5.0 Random Forest](#5.0)
# - [6.0 Neural network](#6.0)
#     - [6.1 preprocessing](#6.1)
#     - [6.2 neural network model 1](#6.2)
#     - [6.3 neural network model 2](#6.3)

# %%
# !pip install category_encoders

# %%
import warnings
warnings.filterwarnings("ignore")


import numpy as np 
import pandas as pd 

import matplotlib.pyplot as plt
import seaborn as sns
import datetime

import re


import gc
import random
import datetime
import decimal
import time
import joblib as jb

import lightgbm as lgb
from category_encoders import HashingEncoder
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.decomposition import PCA
from sklearn.metrics import roc_auc_score, confusion_matrix, classification_report, precision_recall_curve
from sklearn.metrics import  plot_confusion_matrix, precision_score, PrecisionRecallDisplay, recall_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold, train_test_split, cross_val_score, GridSearchCV

import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.initializers import Constant
from tensorflow.keras.metrics import Precision, Recall, AUC

# %matplotlib inline

pd.options.display.max_rows = 10000
pd.options.display.max_columns = 10000
pd.options.display.max_colwidth = 1000

plt.style.use('fivethirtyeight')

# %% [markdown]
# <a id = '1.0'><a/>
# ### 1.0 Functions
# * [Back To Top](#Content)

# %%
def display_scores(name, gsearch, xtrain, xtest, ytrain, ytest):
    """ the function takes a fitted gridsearchcv as the arguement and
    displays scores
    """
    print('='*30)
    print(f"\033[1m {name} \033[0m".center(38, "="))
    print('='*30)
    print('\nScores:')
    print('-'*30, '\n')
    print('train score:', round(gsearch.score(xtrain, ytrain),2))
    print('test score:', round(gsearch.score(xtest, ytest),2))
    print('cross-validated score:', round(gsearch.best_score_,2))
    print('')
    print(" Best Parameters:")
    print('-'*30, '\n')
    for key, value in gsearch.best_params_.items():
        print(key,':', value)

# %%
def plot_cmatrix(ytest, predict):
    """ plot notFraud/isFraud confusion matrix and recall/accuracy stats,
    renamed, as there are no real 'positive' or 'negative' outcome
    """
    cm = pd.DataFrame(confusion_matrix(ytest, predict),
                 index=['notFraud', 'isFraud'],
                 columns=['Predicted notFraud', 'Predicted isFraud'])
    tn, fp, fn, tp = confusion_matrix(ytest, predict).ravel()
    
    print('\n\n***Confusion Matrix***\n')
    display(cm)
    print('\nScores:')
    print('-'*30, '\n')
    print('Fraud recall:  ', round(tp/(tp+fn),2))
    print('Fraud precision:', round(tp/(tp+fp),2))

# %%
def reduce_mem_usage(df):
    """ downcast column data types to reduce memory usage      
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    temp = df.columns.to_list()
    temp.remove('TransactionAmt')
    for col in temp:
        col_type = df[col].dtype
#         if col = ''
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')
        

    end_mem = df.memory_usage().sum() / 1024**2
#     print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
#     print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    print(f'Memory usage of dataframe is {start_mem:.2f} MB --> {end_mem:.2f} MB (Decreased by {100*(start_mem-end_mem)/start_mem:.1f}%)')
    
    del temp
    gc.collect()
    return df

# %%
def fast_auc(y_true, y_prob):
    """
    fast roc_auc computation: https://www.kaggle.com/c/microsoft-malware-prediction/discussion/76013
    """
    y_true = np.asarray(y_true)
    y_true = y_true[np.argsort(y_prob)]
    nfalse = 0
    auc = 0
    n = len(y_true)
    for i in range(n):
        y_i = y_true[i]
        nfalse += (1 - y_i)
        auc += y_i * nfalse
    auc /= (nfalse * (n - nfalse))
    return auc


def eval_auc(y_true, y_pred):
    """
    Fast auc eval function for lgb.
    """
    return 'auc', fast_auc(y_true, y_pred), True

# %%
train = pd.read_csv('../datasets/train_4lgb_cdr.csv', parse_dates=['DT'])
test = pd.read_csv('../datasets/test_4lgb_cdr.csv', parse_dates=['DT'])

# %%
# copy and past from notebook1 output cell
cat_col = ['ProductCD','card1','card2','card3','card4','card5','card6','addr1','addr2','P_emaildomain',
 'R_emaildomain','M4','id_13','id_14','id_15','id_16','id_17','id_19','id_20','id_28','id_29','id_30','id_31','id_32',
 'id_33','id_34','id_35','id_37','id_38','DeviceType','DeviceInfo','DT_M','DT_W','hour','dow',
 'day','addr1_card1','weekday_hour','id_12','M2','M3','M5','M6','M7','M8','M9']

# %%
train.drop('DT', axis=1, inplace=True)
test.drop('DT', axis=1, inplace=True)

# %%
for col in train.columns:
    if col in cat_col:
        train[col] = train[col].fillna('unknown')
        test[col] = test[col].fillna('unknown')

# %%
train = reduce_mem_usage(train)
test = reduce_mem_usage(test)
# Out:
# Memory usage of dataframe is 419.01 MB
# Memory usage of dataframe is 419.01 MB --> 94.44 MB (Decreased by 77.5%)
# Memory usage of dataframe is 355.65 MB
# Memory usage of dataframe is 355.65 MB --> 81.71 MB (Decreased by 77.0%)

# %% [markdown]
# <a id = '2.0'><a/>
# ### 2.0 Null values
# * [Back To Top](#Content)

# %%
train.isnull().sum()
# Out:
# TransactionID                0
# isFraud                      0
# TransactionDT                0
# TransactionAmt               0
# ProductCD                    0
# card1                        0
# card2                        0
# card3                        0
# card4                        0
# card5                        0
# card6                        0
# addr1                        0
# addr2                        0
# dist1                   352271
# P_emaildomain                0
# R_emaildomain                0
# C1                           0
# C2                           0
# C4                           0
# C5                           0
# C6                           0
# C7                           0
# C8                           0
# C9                           0
# C10                          0
# C11                          0
# C12                          0
# C13                          0
# C14                          0
# D1                        1269
# D2                      280797
# D3                      262878
# D4                      168922
# D5                      309841
# D6                      517353
# D8                      515614
# D9                      515614
# D10                      76022
# D11                     279287
# D12                     525823
# D13                     528588
# D14                     528353
# D15                      89113
# M2                           0
# M3                           0
# M4                           0
# M5                           0
# M6                           0
# M7                           0
# M8                           0
# M9                           0
# id_01                   446307
# id_02                   449668
# id_05                   453675
# id_06                   453675
# id_13                        0
# id_14                        0
# id_15                        0
# id_16                        0
# id_17                        0
# id_19                        0
# id_20                        0
# id_28                        0
# id_29                        0
# id_30                        0
# id_31                        0
# id_32                        0
# id_33                        0
# id_34                        0
# id_35                        0
# id_37                        0
# id_38                        0
# DeviceType                   0
# DeviceInfo                   0
# nulls                        0
# DT_M                         0
# DT_W                         0
# DT_D                         0
# hour                         0
# dow                          0
# day                          0
# Transaction_decimals         0
# card1_count                  0
# card2_count                  0
# v_avg                        0
# addr1_card1                  0
# weekday_hour                 0
# P_emaildomain_f_enc          0
# amt_per_product              0
# vcol_pca0                    0
# vcol_pca1                    0
# is_december                  0
# id_12                        0
# dtype: int64

# %%
# impute D columns (not DT or Device) with their mean
for col in train.columns:
    if col[0]=='D' and col[1] not in['T', 'e']:
        train[col].fillna(train[col].astype(np.float32).mean(), inplace=True)
        test[col].fillna(test[col].astype(np.float32).mean(), inplace=True)

# %%
train['dist1'].dtype
# Out:
# dtype('float16')

# %%
# impute numberical dist1 column with its mean
train['dist1'].fillna(train['dist1'].astype(np.float32).mean(), inplace=True)
test['dist1'].fillna(test['dist1'].astype(np.float32).mean(), inplace=True)

# %%
# columns id1,2,5 and 6 have many nulls. drop them.
train.drop(columns=['id_01', 'id_02', 'id_05', 'id_06'], inplace=True)
test.drop(columns=['id_01', 'id_02', 'id_05', 'id_06'], inplace=True)

# %%
train.isnull().sum().sum()
# Out:
# 0

# %%
test.isnull().sum().sum()
# Out:
# 0

# %%
lst = [f'C{i}' for i in range(1,15)]
lst.remove('C3')
for col in lst:
    test[col].fillna(test[col].astype(np.float32).mean(), inplace=True)

# %%
test.drop(['DT_M'], axis=1, inplace=True)
train.drop(['DT_M'], axis=1, inplace=True)

cat_col.remove('DT_M')

# %% [markdown]
# <a id = '3.0'><a/>
# ### 3.0 Encoding
# * [Back To Top](#Content)

# %%
encode = []
dummy = []
for col in cat_col:
    if train[col].nunique()>7:
        encode.append(col)
    else:
        dummy.append(col)

# %%
dummy
# Out:
# ['ProductCD',
#  'card4',
#  'card6',
#  'M4',
#  'id_15',
#  'id_16',
#  'id_28',
#  'id_29',
#  'id_32',
#  'id_34',
#  'id_35',
#  'id_37',
#  'id_38',
#  'DeviceType',
#  'dow',
#  'id_12',
#  'M2',
#  'M3',
#  'M5',
#  'M6',
#  'M7',
#  'M8',
#  'M9']

# %%
train = pd.get_dummies(train, columns=dummy, drop_first=True)
test = pd.get_dummies(test, columns=dummy, drop_first=True)

# %%
train.shape, test.shape
# Out:
# ((590540, 128), (506691, 127))

# %%
set(train.columns)-set(test.columns),set(test.columns)-set(train.columns)
# Out:
# ({'isFraud'}, set())

# %%
test['card6_debit or credit'] = 0
test['id_34_match_status:0'] = 0
test['id_34_match_status:1'] = 0

train['id_32_48.0'] = 0

# %%
encode
# Out:
# ['card1',
#  'card2',
#  'card3',
#  'card5',
#  'addr1',
#  'addr2',
#  'P_emaildomain',
#  'R_emaildomain',
#  'id_13',
#  'id_14',
#  'id_17',
#  'id_19',
#  'id_20',
#  'id_30',
#  'id_31',
#  'id_33',
#  'DeviceInfo',
#  'DT_W',
#  'hour',
#  'day',
#  'addr1_card1',
#  'weekday_hour']

# %%
# train.to_csv('../datasets/train_enc2.csv', index=False)
# test.to_csv('../datasets/test_enc2.csv', index=False)

# %%
X = train.sort_values('TransactionDT').drop(
    ['isFraud', 'DT_D', 'TransactionDT', 'TransactionID'], axis=1)
X_kaggletest = test.sort_values('TransactionDT').drop(
    ['DT_D', 'TransactionDT', 'TransactionID'], axis=1)
y = train.sort_values('TransactionDT')['isFraud']

# %%
he = HashingEncoder(cols=encode).fit(X, y)

# %%
X = he.transform(X)
test_enc = he.transform(X_kaggletest)

# %%
X = X.rename(columns = lambda x:re.sub('[^A-Za-z0-9_]+', '', x))
test_enc = test_enc.rename(columns = lambda x:re.sub('[^A-Za-z0-9_]+', '', x))

# %%
scoring_table=[]
scoring_table_load=[]
result_dict={}

# %% [markdown]
# <a id = '4.0'><a/>
# ### 4.0 light gbm w dummy- and hash-encoding
# * [Back To Top](#Content)

# %% [markdown]
# <a id = '4.1'><a/>
# #### 4.1 light gbm 2 (encoded version)
# * [Back To Top](#Content)

# %%
n_fold = 5
folds = KFold(n_splits=n_fold)

params = {'num_leaves': 128, 
          'min_child_samples': 79,
          'objective': 'binary',
          'max_depth': 13,
          'learning_rate': 0.02, #0.03
          "boosting_type": "gbdt",
          "subsample_freq": 2, #3
          "subsample": 0.8, #0.9
          "bagging_seed": 11,
          "metric": 'auc',
          "verbosity": -1,
          'reg_alpha': 0.3,
          'reg_lambda': 0.2, #0.3
          'colsample_bytree': 0.8, #0.9
          #'categorical_feature': cat_cols
         }

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5,
                                                    shuffle=False,  random_state=42)

# %%
columns = X.columns 
n_splits = folds.n_splits 
X_test = X_test[columns]
    

    
# out-of-fold predictions on train data
oof = np.zeros((len(X), 1))

# averaged predictions on test data
prediction = np.zeros((len(X_test), 1))
        
   # list of scores on folds
scores = []
feature_importance = pd.DataFrame()
    
# split and train on folds
for fold_n, (foldtrain_index, valid_index) in enumerate(folds.split(X_train)):
    print(f'Fold {fold_n + 1} started at {time.ctime()}')
        
    X_foldtrain, X_valid = X[columns].iloc[foldtrain_index], X[columns].iloc[valid_index]
    y_foldtrain, y_valid = y.iloc[foldtrain_index], y.iloc[valid_index]
            
    model_lgb_enc = lgb.LGBMClassifier(**params, n_estimators=300, n_jobs = -1)
    model_lgb_enc.fit(X_foldtrain, y_foldtrain, 
            eval_set=[(X_foldtrain, y_foldtrain), (X_valid,
                                                   y_valid)], eval_metric=eval_auc,
            early_stopping_rounds=200)
            
    y_pred_valid = model_lgb_enc.predict_proba(X_valid)[:, 1]
    y_pred = model_lgb_enc.predict_proba(X_test,
                                         num_iteration=model_lgb_enc.best_iteration_)[:, 1]
            
             
    oof[valid_index] = y_pred_valid.reshape(-1, 1)
    scores.append(roc_auc_score(y_valid, y_pred_valid))
            
    prediction += y_pred.reshape(-1, 1)

              
        
        
    # feature importance
    fold_importance = pd.DataFrame()
    fold_importance["feature"] = columns
    fold_importance["importance"] = model_lgb_enc.feature_importances_
    fold_importance["fold"] = fold_n + 1
    feature_importance = pd.concat([feature_importance, fold_importance], axis=0)
# Out:
# Fold 1 started at Thu Feb 24 14:43:16 2022
# [1]	training's auc: 0.870569	training's auc: 0.86817	valid_1's auc: 0.82585	valid_1's auc: 0.826367
# [2]	training's auc: 0.879788	training's auc: 0.877597	valid_1's auc: 0.840409	valid_1's auc: 0.840857
# [297]	training's auc: 0.981132	training's auc: 0.981132	valid_1's auc: 0.927943	valid_1's auc: 0.927943
# [298]	training's auc: 0.981218	training's auc: 0.981218	valid_1's auc: 0.927982	valid_1's auc: 0.927982
# [299]	training's auc: 0.981291	training's auc: 0.981291	valid_1's auc: 0.927959	valid_1's auc: 0.927959
# [300]	training's auc: 0.981374	training's auc: 0.981374	valid_1's auc: 0.92798	valid_1's auc: 0.92798

# %%
prediction /= n_splits
    
print(f'CV mean score: {np.mean(scores):.4f}, std: {np.std(scores):.4f}.')
    
result_dict['oof_e1'] = oof
result_dict['prediction_e1'] = prediction
result_dict['scores_e1'] = scores
    


feature_importance["importance"] /= n_splits
cols = feature_importance[["feature", "importance"]].groupby("feature").mean().sort_values(
                                               by="importance", ascending=False)[:30].index

best_features = feature_importance.loc[feature_importance.feature.isin(cols)]

plt.figure(figsize=(16, 12));
sns.barplot(x="importance", y="feature", data=best_features.sort_values(
                                                            by="importance", ascending=False));
plt.title('LGB Features (avg over folds)');
            
result_dict['feature_importance_e1'] = feature_importance
result_dict['top_columns_e1'] = cols
# Out:
# CV mean score: 0.9243, std: 0.0108.

# %%
prediction_label = prediction.round()
print()
print(classification_report(y_test, prediction_label))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99    284501
#            1       0.81      0.32      0.46     10769
#
#     accuracy                           0.97    295270
#    macro avg       0.89      0.66      0.72    295270
# weighted avg       0.97      0.97      0.97    295270

# %%
plot_confusion_matrix(model_lgb_enc, X_test, y_test);

# %%
model_lgb_enc.get_params
# Out:
# <bound method LGBMModel.get_params of LGBMClassifier(bagging_seed=11, colsample_bytree=0.8, learning_rate=0.02,
#                max_depth=13, metric='auc', min_child_samples=79,
#                n_estimators=300, num_leaves=128, objective='binary',
#                reg_alpha=0.3, reg_lambda=0.2, subsample=0.8, subsample_freq=2,
#                verbosity=-1)>

# %%
# filename_model_lgb_enc = '../Models/model_ljg_enc.sav'
# test_loading1 = jb.load(filename_model_lgb_enc)

# %%
table = {'Model': 'LGBM_enc1'}
table['CV mean ROC-AUC'] = np.mean(scores)
table['ROC-AUC-train'] = roc_auc_score(y_train, oof[:len(X_train)])
table['ROC-AUC-test'] = roc_auc_score(y_test, prediction)
table['Precision'] = precision_score(y_test, prediction_label)
table['Recall'] = recall_score(y_test, prediction_label)

scoring_table.append(table)

# %%
# table_load = {'Model': 'LGBM1'}
# table_load['ROC-AUC-train'] = roc_auc_score(y_train, test_loading.predict_proba(X_train)[:,1])
# table_load['ROC-AUC-test'] = roc_auc_score(y_test, test_loading.predict_proba(X_test)[:,1])
# table_load['Precision'] = precision_score(y_test, test_loading.predict(X_test))
# table_load['Recall'] = recall_score(y_test, test_loading.predict(X_test))

# scoring_table_load.append(table_load)

# %%
table
# Out:
# {'Model': 'LGBM_enc1',
#  'CV mean ROC-AUC': 0.9242801082771159,
#  'ROC-AUC-train': 0.9254746112929142,
#  'ROC-AUC-test': 0.8988196375723794,
#  'Precision': 0.8115737473535639,
#  'Recall': 0.32036400780016716}

# %%
# print('ROC-AUC on test data:', round(roc_auc_score(y_test, prediction),4))

# %%
# filename_model_lgb_enc = '../Models/model_lgb_enc.sav'
# jb.dump(model_lgb_enc, filename_model_lgb_enc)

# %%
# prediction_lgb_enc=prediction

# %% [markdown]
# <a id = '4.2'><a/>
# #### 4.2 same as 4.1 w pos weights
# * [Back To Top](#Content)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.75,
                                                    shuffle=False,  random_state=42)

# %%
params = {'num_leaves': 126,#256
          'min_child_samples': 79,
          'objective': 'binary',
          'max_depth': 15, #13
          'learning_rate': 0.02, #0.03
          "boosting_type": "gbdt",
          "subsample_freq": 2, #3
          "subsample": 0.8, #0.9
          "bagging_seed": 15, #11
          "metric": 'auc',
          "verbosity": -1,
          'reg_alpha': 0.2, #0.3
#           'reg_lambda': 0.2, #0.3
          'colsample_bytree': 0.8, #0.9,
          'scale_pos_weight': 60 # THIS IS THE KEY ADDITION
         }

# %%
columns = X.columns 
n_splits = folds.n_splits 
X_test = X_test[columns]
    

    
# out-of-fold predictions on train data
oof = np.zeros((len(X), 1))

# averaged predictions on test data
prediction = np.zeros((len(X_test), 1))
        
   # list of scores on folds
scores = []
feature_importance = pd.DataFrame()
    
# split and train on folds
for fold_n, (foldtrain_index, valid_index) in enumerate(folds.split(X_train)):
    print(f'Fold {fold_n + 1} started at {time.ctime()}')
        
    X_foldtrain, X_valid = X[columns].iloc[foldtrain_index], X[columns].iloc[valid_index]
    y_foldtrain, y_valid = y.iloc[foldtrain_index], y.iloc[valid_index]
            
    model_lgb_enc_W = lgb.LGBMClassifier(**params, n_estimators=400, n_jobs = -1)
    model_lgb_enc_W.fit(X_foldtrain, y_foldtrain, 
            eval_set=[(X_foldtrain, y_foldtrain), (X_valid, y_valid)], eval_metric=eval_auc,
            early_stopping_rounds=200)
            
    y_pred_valid = model_lgb_enc_W.predict_proba(X_valid)[:, 1]
    y_pred = model_lgb_enc_W.predict_proba(X_test, num_iteration=model_lgb_enc_W.best_iteration_)[:, 1]
            
             
    oof[valid_index] = y_pred_valid.reshape(-1, 1)
    scores.append(roc_auc_score(y_valid, y_pred_valid))
            
    prediction += y_pred.reshape(-1, 1)

              
        
        
    # feature importance
    fold_importance = pd.DataFrame()
    fold_importance["feature"] = columns
    fold_importance["importance"] = model_lgb_enc_W.feature_importances_
    fold_importance["fold"] = fold_n + 1
    feature_importance = pd.concat([feature_importance, fold_importance], axis=0)
# Out:
# Fold 1 started at Thu Feb 24 17:55:17 2022
# [1]	training's auc: 0.901579	training's auc: 0.901776	valid_1's auc: 0.789804	valid_1's auc: 0.789907
# [2]	training's auc: 0.922473	training's auc: 0.922468	valid_1's auc: 0.821185	valid_1's auc: 0.821218
# [3]	training's auc: 0.93651	training's auc: 0.936537	valid_1's auc: 0.840637	valid_1's auc: 0.84064
# [4]	training's auc: 0.942877	training's auc: 0.942906	valid_1's auc: 0.847408	valid_1's auc: 0.847331
# [5]	training's auc: 0.949341	training's auc: 0.949361	valid_1's auc: 0.855329	valid_1's auc: 0.855322
# [400]	training's auc: 0.999243	training's auc: 0.999243	valid_1's auc: 0.905515	valid_1's auc: 0.905515

# %%
prediction /= n_splits
    
print(f'CV mean score: {np.mean(scores):.4f}, std: {np.std(scores):.4f}.')
    
result_dict['oof_e2'] = oof
result_dict['prediction_e2'] = prediction
result_dict['scores_e2'] = scores
    


feature_importance["importance"] /= n_splits
cols = feature_importance[["feature", "importance"]].groupby("feature").mean().sort_values(
                                               by="importance", ascending=False)[:50].index

best_features = feature_importance.loc[feature_importance.feature.isin(cols)]

plt.figure(figsize=(16, 12));
sns.barplot(x="importance", y="feature", data=best_features.sort_values(
                                                            by="importance", ascending=False));
plt.title('LGB Features (avg over folds)');
            
result_dict['feature_importance_e2'] = feature_importance
result_dict['top_columns_e2'] = cols
        
# return result_dict
# Out:
# CV mean score: 0.9065, std: 0.0046.

# %%
prediction_label = prediction.round()
print()
print(classification_report(y_test, prediction_label))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97    426130
#            1       0.37      0.51      0.43     16775
#
#     accuracy                           0.95    442905
#    macro avg       0.67      0.74      0.70    442905
# weighted avg       0.96      0.95      0.95    442905

# %%
plot_confusion_matrix(model_lgb_enc_W, X_test, y_test);

# %%
model_lgb_enc_W.get_params
# Out:
# <bound method LGBMModel.get_params of LGBMClassifier(bagging_seed=15, colsample_bytree=0.8, learning_rate=0.02,
#                max_depth=15, metric='auc', min_child_samples=79,
#                n_estimators=400, num_leaves=126, objective='binary',
#                reg_alpha=0.2, scale_pos_weight=60, subsample=0.8,
#                subsample_freq=2, verbosity=-1)>

# %%
# filename_model_lgb_enc_W = '../Models/model_lgb_enc_W.sav'
# test_loading2 = jb.load(filename_model_lgb_enc_W)

# %%
table = {'Model': 'LGBM_enc2_W'}
table['CV mean ROC-AUC'] = np.mean(scores)
table['ROC-AUC-train'] = roc_auc_score(y_train, oof[:len(X_train)])
table['ROC-AUC-test'] = roc_auc_score(y_test, prediction)
table['Precision'] = precision_score(y_test, prediction_label)
table['Recall'] = recall_score(y_test, prediction_label)

scoring_table.append(table)

# %%
# table_load = {'Model': 'LGBM1'}
# table_load['ROC-AUC-train'] = roc_auc_score(y_train, test_loading.predict_proba(X_train)[:,1])
# table_load['ROC-AUC-test'] = roc_auc_score(y_test, test_loading.predict_proba(X_test)[:,1])
# table_load['Precision'] = precision_score(y_test, test_loading.predict(X_test))
# table_load['Recall'] = recall_score(y_test, test_loading.predict(X_test))

# scoring_table_load.append(table_load)

# %%
# filename_model_lgb_enc_W = '../Models/model_lgb_enc_W.sav'
# jb.dump(model_lgb_enc_W, filename_model_lgb_enc_W)

# %% [markdown]
# <a id = '4.3'><a/>
# #### 4.3 same as 4.1 w 32-bit hash-encoding
# * [Back To Top](#Content)

# %%
XXX = train.sort_values('TransactionDT').drop(
    ['isFraud', 'DT_D', 'TransactionDT', 'TransactionID'], axis=1)
# X_kaggletest = test.sort_values('TransactionDT').drop(
#     ['DT_D', 'TransactionDT', 'TransactionID'], axis=1)
# y = train.sort_values('TransactionDT')['isFraud']

# %%
he = HashingEncoder(cols=encode, n_components=32).fit(XXX, y)

# %%
XXX = he.transform(XXX)

# %%
XXX = XXX.rename(columns = lambda x:re.sub('[^A-Za-z0-9_]+', '', x))

# %%
n_fold = 5
folds = KFold(n_splits=n_fold)

params = {'num_leaves': 128, 
          'min_child_samples': 79,
          'objective': 'binary',
          'max_depth': 13,
          'learning_rate': 0.02, #0.03
          "boosting_type": "gbdt",
          "subsample_freq": 2, #3
          "subsample": 0.8, #0.9
          "bagging_seed": 11,
          "metric": 'auc',
          "verbosity": -1,
          'reg_alpha': 0.3,
          'reg_lambda': 0.2, #0.3
          'colsample_bytree': 0.8, #0.9
          #'categorical_feature': cat_cols
         }

# %%
X_train, X_test, y_train, y_test = train_test_split(XXX, y, test_size=0.5,
                                                    shuffle=False,  random_state=42)

# %%
columns = XXX.columns 
n_splits = folds.n_splits 
X_test = X_test[columns]
    

    
# out-of-fold predictions on train data
oof = np.zeros((len(XXX), 1))

# averaged predictions on test data
prediction = np.zeros((len(X_test), 1))
        
   # list of scores on folds
scores = []
feature_importance = pd.DataFrame()
    
# split and train on folds
for fold_n, (foldtrain_index, valid_index) in enumerate(folds.split(X_train)):
    print(f'Fold {fold_n + 1} started at {time.ctime()}')
        
    X_foldtrain, X_valid = XXX[columns].iloc[foldtrain_index], XXX[columns].iloc[valid_index]
    y_foldtrain, y_valid = y.iloc[foldtrain_index], y.iloc[valid_index]
            
    model_lgb_enc32 = lgb.LGBMClassifier(**params, n_estimators=300, n_jobs = -1)
    model_lgb_enc32.fit(X_foldtrain, y_foldtrain, 
            eval_set=[(X_foldtrain, y_foldtrain), (X_valid, y_valid)], eval_metric=eval_auc,
            early_stopping_rounds=200)
            
    y_pred_valid = model_lgb_enc32.predict_proba(X_valid)[:, 1]
    y_pred = model_lgb_enc32.predict_proba(X_test, num_iteration=model_lgb_enc32.best_iteration_)[:, 1]
            
             
    oof[valid_index] = y_pred_valid.reshape(-1, 1)
    scores.append(roc_auc_score(y_valid, y_pred_valid))
            
    prediction += y_pred.reshape(-1, 1)

              
        
        
    # feature importance
    fold_importance = pd.DataFrame()
    fold_importance["feature"] = columns
    fold_importance["importance"] = model_lgb_enc32.feature_importances_
    fold_importance["fold"] = fold_n + 1
    feature_importance = pd.concat([feature_importance, fold_importance], axis=0)
# Out:
# Fold 1 started at Thu Feb 24 22:13:45 2022
# [1]	training's auc: 0.868361	training's auc: 0.865845	valid_1's auc: 0.815103	valid_1's auc: 0.814808
# [2]	training's auc: 0.881923	training's auc: 0.881116	valid_1's auc: 0.833118	valid_1's auc: 0.833453
# [3]	training's auc: 0.886699	training's auc: 0.886125	valid_1's auc: 0.841967	valid_1's auc: 0.842217
# [4]	training's auc: 0.889446	training's auc: 0.889351	valid_1's auc: 0.842321	valid_1's auc: 0.842393
# [5]	training's auc: 0.891962	training's auc: 0.891847	valid_1's auc: 0.845034	valid_1's auc: 0.845126
# [6]	training's auc: 0.894198	training's auc: 0.893846	valid_1's auc: 0.847214	valid_1's auc: 0.847693
# [7]	training's auc: 0.895212	training's auc: 0.895143	valid_1's auc: 0.848268	valid_1's auc: 0.847867
# %%
prediction /= n_splits
    
print(f'CV mean score: {np.mean(scores):.4f}, std: {np.std(scores):.4f}.')
    
result_dict['oof_e3'] = oof
result_dict['prediction_e3'] = prediction
result_dict['scores_e3'] = scores
    


feature_importance["importance"] /= n_splits
cols = feature_importance[["feature", "importance"]].groupby("feature").mean().sort_values(
                                               by="importance", ascending=False)[:50].index

best_features = feature_importance.loc[feature_importance.feature.isin(cols)]

plt.figure(figsize=(16, 12));
sns.barplot(x="importance", y="feature", data=best_features.sort_values(
                                                            by="importance", ascending=False));
plt.title('LGB Features (avg over folds)');
            
result_dict['feature_importance_e3'] = feature_importance
result_dict['top_columns_e3'] = cols
# Out:
# CV mean score: 0.9239, std: 0.0110.

# %%
prediction_label = prediction.round()
print()
print(classification_report(y_test, prediction_label))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99    284501
#            1       0.82      0.32      0.46     10769
#
#     accuracy                           0.97    295270
#    macro avg       0.90      0.66      0.72    295270
# weighted avg       0.97      0.97      0.97    295270

# %%
plot_confusion_matrix(model_lgb_enc32, X_test, y_test)

# %%
model_lgb_enc32.get_params
# Out:
# <bound method LGBMModel.get_params of LGBMClassifier(bagging_seed=11, colsample_bytree=0.8, learning_rate=0.02,
#                max_depth=13, metric='auc', min_child_samples=79,
#                n_estimators=300, num_leaves=128, objective='binary',
#                reg_alpha=0.3, reg_lambda=0.2, subsample=0.8, subsample_freq=2,
#                verbosity=-1)>

# %%
# filename_model_lgb_enc32 = '../Models/model_lgb_enc32.sav'
# test_loading3 = jb.load(filename_model_lgb_enc32)

# %%
table = {'Model': 'LGBM_enc32'}
table['CV mean ROC-AUC'] = np.mean(scores)
table['ROC-AUC-train'] = roc_auc_score(y_train, oof[:len(X_train)])
table['ROC-AUC-test'] = roc_auc_score(y_test, prediction)
table['Precision'] = precision_score(y_test, prediction_label)
table['Recall'] = recall_score(y_test, prediction_label)

scoring_table.append(table)

# %%
table
# Out:
# {'Model': 'LGBM_enc32',
#  'CV mean ROC-AUC': 0.9239109462254117,
#  'ROC-AUC-train': 0.925275221536445,
#  'ROC-AUC-test': 0.9001890538059367,
#  'Precision': 0.8185053380782918,
#  'Recall': 0.32036400780016716}

# %%
# table_load = {'Model': 'LGBM1'}
# table_load['ROC-AUC-train'] = roc_auc_score(y_train, test_loading.predict_proba(X_train)[:,1])
# table_load['ROC-AUC-test'] = roc_auc_score(y_test, test_loading.predict_proba(X_test)[:,1])
# table_load['Precision'] = precision_score(y_test, test_loading.predict(X_test))
# table_load['Recall'] = recall_score(y_test, test_loading.predict(X_test))

# scoring_table_load.append(table_load)

# %%
# print('ROC-AUC on test data:', round(roc_auc_score(y_test, prediction),4))

# %%
# filename_model_lgb_enc32 = '../Models/model_lgb_enc32.sav'
# jb.dump(model_lgb_enc32, filename_model_lgb_enc32)

# %%
# prediction_lgb_enc32=prediction

# %%
# display_scores('Light GBM 32bit_encode', model_lgb_enc32, X_train, X_test, y_train, y_test)

# %% [markdown]
# <a id = '5.0'><a/>
# ### 5.0 Random Forest
# * [Back To Top](#Content)

# %%
X.shape
# Out:
# (590540, 110)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,
                                                    shuffle=False,  random_state=42)

# %%
param_rf1 = {
    'criterion': ['gini'],
    'ccp_alpha':[0],
    'max_depth': [25],
    'max_features': [8,12],
    'min_samples_split': [100],
    'n_estimators': [300]
}

# %%
# rf1 = RandomForestClassifier(random_state=42)

# %%
# gs_rf1 = GridSearchCV(estimator = rf1, param_grid = param_rf1, scoring='roc_auc',
#                           cv = 5, n_jobs = -1, verbose = 1000)
# gs_rf1.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42), n_jobs=-1,
#              param_grid={'ccp_alpha': [0], 'criterion': ['gini'],
#                          'max_depth': [25], 'max_features': [8, 12],
#                          'min_samples_split': [100], 'n_estimators': [300]},
#              scoring='roc_auc', verbose=1000)

# %%
# gs_rf1.best_params_

# %%
filename_gs_rf1_be = '../Models/gs_rf1_be.sav'
gs_rf1 = jb.load(filename_gs_rf1_be)

# filename_gs_rf1 = '../Models/gs_rf1.sav'
# jb.dump(gs_rf1.best_estimator_, filename_gs_rf1)

# %%
gs_rf1
# Out:
# RandomForestClassifier(ccp_alpha=0, max_depth=25, max_features=10,
#                        min_samples_split=50, n_estimators=450, random_state=42)

# %%
print(classification_report(y_test, gs_rf1.predict(X_test)),'/n')
print('best params: ', gs_rf1)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99    171037
#            1       0.84      0.26      0.40      6125
#
#     accuracy                           0.97    177162
#    macro avg       0.91      0.63      0.69    177162
# weighted avg       0.97      0.97      0.97    177162
#  /n
# best params:  GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42), n_jobs=-1,
#              param_grid={'ccp_alpha': [0], 'criterion': ['gini'],
#                          'max_depth': [25], 'max_features': [8, 12],
#                          'min_samples_split': [100], 'n_estimators': [300]},
#              scoring='roc_auc', verbose=1000)

# %%
plot_confusion_matrix(gs_rf1, X_test, y_test)

# %%
feat_imp = gs_rf1.best_estimator_.feature_importances_

# %%
top_features = pd.DataFrame({'feature': X.columns , 'importance': feat_imp}).sort_values(
    ['importance'], ascending=False).iloc[:30,:]

# %%
fig, ax = plt.subplots(figsize=(8,8))
sns.barplot(x=top_features['importance'] , y = top_features['feature'])
plt.title('RF feature importance', fontsize=14, 
            color='Darkorchid')
plt.xlabel(None)
plt.ylabel(None)
plt.show()

# %%
table = {'Model': 'RF1'}
table['CV mean ROC-AUC'] = gs_rf1.best_score_
table['ROC-AUC-train'] = gs_rf1.score(X_train, y_train)
table['ROC-AUC-test'] = gs_rf1.score(X_test, y_test)
table['Precision'] = precision_score(y_test, gs_rf1.predict(X_test))
table['Recall'] = recall_score(y_test, gs_rf1.predict(X_test))
table
# Out:
# {'Model': 'RF1',
#  'CV mean ROC-AUC': 0.8965494117221681,
#  'ROC-AUC-train': 0.9763664284217599,
#  'ROC-AUC-test': 0.8866158364349617,
#  'Precision': 0.8433351035581519,
#  'Recall': 0.25926530612244897}

# %%
scoring_table.append(table)

# %%
# print('best params: ', gs_rf1.best_params_)
# print('train score: ', gs_rf1.score(X_train, y_train))
# print('test score: ', gs_rf1.score(X_test, y_test))
# print('cross-val score: ', gs_rf1.best_score_)

# %%
# filename_gs_rf1 = '../Models/gs_rf1.sav'
# filename_gs_rf1_be = '../Models/gs_rf1_be.sav'
# jb.dump(gs_rf1.best_estimator_, filename_gs_rf1_be)
# jb.dump(gs_rf1, filename_gs_rf1)
# Out:
# ['../Models/gs_rf1.sav']

# %% [markdown]
# <a id = '6.0'><a/>
# ### 6.0 Neural nework
# * [Back To Top](#Content)

# %% [markdown]
# <a id = '6.1'><a/>
# #### 6.1 Preprocessing
# * [Back To Top](#Content)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5,
                                                    shuffle=False,  random_state=42)

# %%
non_cat = list( set(X_train.columns)-set(cat_col))

# %%
cat_col
# Out:
# ['ProductCD',
#  'card1',
#  'card2',
#  'card3',
#  'card4',
#  'card5',
#  'card6',
#  'addr1',
#  'addr2',
#  'P_emaildomain',
#  'R_emaildomain',
#  'M4',
#  'id_13',
#  'id_14',
#  'id_15',
#  'id_16',
#  'id_17',
#  'id_19',
#  'id_20',
#  'id_28',
#  'id_29',
#  'id_30',
#  'id_31',
#  'id_32',
#  'id_33',
#  'id_34',
#  'id_35',
#  'id_37',
#  'id_38',
#  'DeviceType',
#  'DeviceInfo',
#  'DT_W',
#  'hour',
#  'dow',
#  'day',
#  'addr1_card1',
#  'weekday_hour',
#  'id_12',
#  'M2',
#  'M3',
#  'M5',
#  'M6',
#  'M7',
#  'M8',
#  'M9']

# %%
non_cat = [col for col in non_cat if col not in ['is_december', 'vcol_pca0', 'vcol_pca1',
                                                'TransactionDT', 'TransactionID', 'DT_D']]

# %%
mms = MinMaxScaler()

X_train[non_cat] = mms.fit_transform(X_train[non_cat])
X_test[non_cat] = mms.transform(X_test[non_cat])

# %%
pos=y.value_counts(normalize=True)[1]
pos
# Out:
# 0.03499000914417313

# %%
n_input = X_train.shape [1]

pos = y.value_counts(normalize=True)[1]
initial_bias = np.log([pos/(1-pos)])
output_bias = Constant(initial_bias)

# %% [markdown]
# <a id = '6.2'><a/>
# ### 6.2 Neural network models 1
# * [Back To Top](#Content)

# %%
n_input = X_train.shape [1]

early_stop = EarlyStopping(monitor='val_prc', patience=10, verbose=1, mode='max')


pos = y.value_counts(normalize=True)[1]
initial_bias = np.log([pos/(1-pos)])
output_bias = Constant(initial_bias)
Metrics = [
    Precision(name='precision'),
    Recall(name='recall'),
    AUC(name='auc'),
    AUC(name='prc', curve='PR')
]

# %%
model_nn = Sequential()
model_nn.add(Dense(70, input_dim=n_input, activation='relu'))
model_nn.add(Dense(40, activation='relu'))
model_nn.add(Dense(20, activation='relu'))
model_nn.add(Dense(1, activation='sigmoid', bias_initializer=output_bias))


model_nn.compile(loss='bce', optimizer='adam', metrics=Metrics)

# %%
history = model_nn.fit(X_train, y_train, validation_data=(X_test, y_test),
                      epochs=20, batch_size=None, class_weight={0:2, 1:98}, callbacks=[early_stop], verbose=2)
# Out:
# Epoch 1/20
# 9228/9228 - 12s - loss: 2.1442 - precision: 0.1004 - recall: 0.8569 - auc: 0.8844 - prc: 0.3588 - val_loss: 0.6819 - val_precision: 0.0871 - val_recall: 0.7972 - val_auc: 0.8219 - val_prc: 0.2561 - 12s/epoch - 1ms/step
# Epoch 2/20
# 9228/9228 - 13s - loss: 2.1183 - precision: 0.1013 - recall: 0.8598 - auc: 0.8872 - prc: 0.3711 - val_loss: 0.5475 - val_precision: 0.1057 - val_recall: 0.7379 - val_auc: 0.8249 - val_prc: 0.2621 - 13s/epoch - 1ms/step
# Epoch 3/20
# 9228/9228 - 14s - loss: 2.1082 - precision: 0.1026 - recall: 0.8591 - auc: 0.8885 - prc: 0.3822 - val_loss: 0.5459 - val_precision: 0.1064 - val_recall: 0.7302 - val_auc: 0.8262 - val_prc: 0.2500 - 14s/epoch - 1ms/step
# Epoch 4/20
# 9228/9228 - 14s - loss: 2.0857 - precision: 0.1039 - recall: 0.8588 - auc: 0.8910 - prc: 0.3902 - val_loss: 0.5794 - val_precision: 0.0997 - val_recall: 0.7570 - val_auc: 0.8243 - val_prc: 0.2652 - 14s/epoch - 1ms/step
# Epoch 5/20
# 9228/9228 - 14s - loss: 2.0744 - precision: 0.1051 - recall: 0.8603 - auc: 0.8929 - prc: 0.3981 - val_loss: 0.5839 - val_precision: 0.0992 - val_recall: 0.7653 - val_auc: 0.8250 - val_prc: 0.2563 - 14s/epoch - 2ms/step
# Epoch 6/20
# 9228/9228 - 14s - loss: 2.0523 - precision: 0.1072 - recall: 0.8623 - auc: 0.8948 - prc: 0.4084 - val_loss: 0.5638 - val_precision: 0.1021 - val_recall: 0.7521 - val_auc: 0.8267 - val_prc: 0.2686 - 14s/epoch - 2ms/step
# Epoch 7/20
# 9228/9228 - 15s - loss: 2.0433 - precision: 0.1080 - recall: 0.8645 - auc: 0.8966 - prc: 0.4165 - val_loss: 0.6557 - val_precision: 0.0956 - val_recall: 0.7750 - val_auc: 0.8246 - val_prc: 0.2656 - 15s/epoch - 2ms/step
# Epoch 8/20
# 9228/9228 - 15s - loss: 2.0314 - precision: 0.1084 - recall: 0.8605 - auc: 0.8969 - prc: 0.4213 - val_loss: 0.5558 - val_precision: 0.1051 - val_recall: 0.7343 - val_auc: 0.8236 - val_prc: 0.2741 - 15s/epoch - 2ms/step
# Epoch 9/20
# 9228/9228 - 15s - loss: 2.0204 - precision: 0.1094 - recall: 0.8637 - auc: 0.8986 - prc: 0.4278 - val_loss: 0.4503 - val_precision: 0.1227 - val_recall: 0.6726 - val_auc: 0.8235 - val_prc: 0.2681 - 15s/epoch - 2ms/step
# Epoch 10/20
# 9228/9228 - 15s - loss: 2.0027 - precision: 0.1101 - recall: 0.8657 - auc: 0.9000 - prc: 0.4285 - val_loss: 0.5769 - val_precision: 0.1017 - val_recall: 0.7366 - val_auc: 0.8232 - val_prc: 0.2869 - 15s/epoch - 2ms/step
# Epoch 11/20
# 9228/9228 - 15s - loss: 2.0004 - precision: 0.1107 - recall: 0.8646 - auc: 0.9006 - prc: 0.4309 - val_loss: 0.5867 - val_precision: 0.0995 - val_recall: 0.7431 - val_auc: 0.8207 - val_prc: 0.2731 - 15s/epoch - 2ms/step
# Epoch 12/20
# 9228/9228 - 16s - loss: 1.9832 - precision: 0.1115 - recall: 0.8671 - auc: 0.9022 - prc: 0.4404 - val_loss: 0.5034 - val_precision: 0.1079 - val_recall: 0.7129 - val_auc: 0.8188 - val_prc: 0.2742 - 16s/epoch - 2ms/step
# Epoch 13/20
# 9228/9228 - 15s - loss: 1.9747 - precision: 0.1114 - recall: 0.8680 - auc: 0.9033 - prc: 0.4453 - val_loss: 0.6332 - val_precision: 0.0905 - val_recall: 0.7824 - val_auc: 0.8225 - val_prc: 0.2756 - 15s/epoch - 2ms/step
# Epoch 14/20
# 9228/9228 - 16s - loss: 1.9593 - precision: 0.1140 - recall: 0.8732 - auc: 0.9048 - prc: 0.4518 - val_loss: 0.6703 - val_precision: 0.0880 - val_recall: 0.7883 - val_auc: 0.8188 - val_prc: 0.2560 - 16s/epoch - 2ms/step
# Epoch 15/20
# 9228/9228 - 16s - loss: 1.9498 - precision: 0.1136 - recall: 0.8699 - auc: 0.9058 - prc: 0.4506 - val_loss: 0.5264 - val_precision: 0.1076 - val_recall: 0.7293 - val_auc: 0.8260 - val_prc: 0.2918 - 16s/epoch - 2ms/step
# Epoch 16/20
# 9228/9228 - 17s - loss: 1.9473 - precision: 0.1143 - recall: 0.8740 - auc: 0.9061 - prc: 0.4572 - val_loss: 0.5754 - val_precision: 0.1006 - val_recall: 0.7495 - val_auc: 0.8258 - val_prc: 0.2814 - 17s/epoch - 2ms/step
# Epoch 17/20
# 9228/9228 - 17s - loss: 1.9299 - precision: 0.1149 - recall: 0.8730 - auc: 0.9076 - prc: 0.4547 - val_loss: 0.6450 - val_precision: 0.0928 - val_recall: 0.7778 - val_auc: 0.8231 - val_prc: 0.2813 - 17s/epoch - 2ms/step
# Epoch 18/20
# 9228/9228 - 17s - loss: 1.9195 - precision: 0.1155 - recall: 0.8710 - auc: 0.9086 - prc: 0.4630 - val_loss: 0.4836 - val_precision: 0.1158 - val_recall: 0.6921 - val_auc: 0.8216 - val_prc: 0.2855 - 17s/epoch - 2ms/step
# Epoch 19/20
# 9228/9228 - 17s - loss: 1.9127 - precision: 0.1163 - recall: 0.8712 - auc: 0.9097 - prc: 0.4675 - val_loss: 0.5403 - val_precision: 0.1044 - val_recall: 0.7315 - val_auc: 0.8221 - val_prc: 0.2916 - 17s/epoch - 2ms/step
# Epoch 20/20
# 9228/9228 - 17s - loss: 1.9100 - precision: 0.1171 - recall: 0.8713 - auc: 0.9101 - prc: 0.4691 - val_loss: 0.5347 - val_precision: 0.1054 - val_recall: 0.7284 - val_auc: 0.8217 - val_prc: 0.2728 - 17s/epoch - 2ms/step

# %%
model_nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 70)                7770
#
#  dense_1 (Dense)             (None, 40)                2840
#
#  dense_2 (Dense)             (None, 20)                820
#
#  dense_3 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 11,451
# Trainable params: 11,451
# Non-trainable params: 0
# _________________________________________________________________

# %%
results = model_nn.evaluate(X_test, y_test,  verbose=0)
print("Loss: {:0.4f}".format(results[0]))
# Out:
# Loss: 0.5347

# %%
plt.plot(history.epoch, history.history['loss'], c='g');      # green - training loss
plt.plot(history.epoch, history.history['val_loss'], c='b');  # blue - test loss

# %%
pred_model_nn = model_nn.predict(X_test)

# %%
np.round(pred_model_nn).sum()/len(pred_model_nn)
# Out:
# 0.2521556541470519

# %%
plot_cmatrix(y_test, np.round(pred_model_nn))
# Out:
# ***Confusion Matrix***
#           Predicted notFraud  Predicted isFraud
# notFraud              217891              66610
# isFraud                 2925               7844
# Scores:
# ------------------------------
#
# Fraud recall:   0.73
# Fraud precision: 0.11

# %%
roc_auc_score(y_train, model_nn.predict(X_train))
# Out:
# 0.8288812292646751

# %%
table = {'Model': 'CNN1'}

table['CV mean ROC-AUC'] = 'N/A'
table['ROC-AUC-train'] = roc_auc_score(y_train, model_nn.predict(X_train))
table['ROC-AUC-test'] = roc_auc_score(y_test, model_nn.predict(X_test))
table['Precision'] = precision_score(y_test, np.round(pred_model_nn))
table['Recall'] = recall_score(y_test,np.round(pred_model_nn))
table
# Out:
# {'Model': 'CNN1',
#  'CV mean ROC-AUC': 'N/A',
#  'ROC-AUC-train': 0.9156116515089099,
#  'ROC-AUC-test': 0.8217454628760483,
#  'Precision': 0.10535364117441642,
#  'Recall': 0.7283870368650757}

# %%
# model_nn.save('../Models/model_nn.sav')
# model_nn_loaded = keras.models.load_model('../Models/model_nn.sav')

# %%
scoring_table.append(table)

# %% [markdown]
# <a id = '6.3'><a/>
# ### 6.3 Neural network model 3
# * [Back To Top](#Content)

# %% [markdown]
# - add learning rate of 0.01 and in tandem, ReduceLROnPlateau callback to reduce the said learning rate by a factor of 0.3 on each 3 epochs with no improvement in validation auc-roc.

# %%
#callbacks
early_stop = EarlyStopping(monitor='val_auc', patience=15, verbose=1, mode='max')
reduce_lr = ReduceLROnPlateau(monitor='val_auc', factor=0.3,
                              patience=3, min_lr=0.001)


Metrics = [
    Precision(name='precision'),
    Recall(name='recall'),
    AUC(name='auc'),
    AUC(name='prc', curve='PR')
]

# %%
model_nn2 = Sequential()
model_nn2.add(Dense(100, input_dim=n_input, activation='relu'))
model_nn2.add(Dense(50, activation='relu'))
model_nn2.add(Dense(25, activation='relu'))
model_nn2.add(Dense(1, activation='sigmoid', bias_initializer=output_bias))


opt = keras.optimizers.Adam(learning_rate=0.01)
model_nn2.compile(loss='bce', optimizer=opt, metrics=Metrics)

# %%
history_new = model_nn2.fit(X_train, y_train, validation_data=(X_test, y_test),
                      epochs=50, batch_size=None, class_weight={0:3, 1:97}, callbacks=[early_stop, reduce_lr], verbose=2)
# Out:
# Epoch 1/50
# 9228/9228 - 14s - loss: 3.2938 - precision: 0.0895 - recall: 0.7317 - auc: 0.8096 - prc: 0.1696 - val_loss: 0.5255 - val_precision: 0.1025 - val_recall: 0.7132 - val_auc: 0.8146 - val_prc: 0.1930 - lr: 0.0100 - 14s/epoch - 2ms/step
# Epoch 2/50
# 9228/9228 - 13s - loss: 3.1057 - precision: 0.0998 - recall: 0.7568 - auc: 0.8335 - prc: 0.2075 - val_loss: 0.5460 - val_precision: 0.1043 - val_recall: 0.7132 - val_auc: 0.8130 - val_prc: 0.1754 - lr: 0.0100 - 13s/epoch - 1ms/step
# Epoch 3/50
# 9228/9228 - 14s - loss: 3.0428 - precision: 0.1044 - recall: 0.7588 - auc: 0.8411 - prc: 0.2297 - val_loss: 0.3460 - val_precision: 0.1622 - val_recall: 0.5174 - val_auc: 0.8192 - val_prc: 0.2131 - lr: 0.0100 - 14s/epoch - 2ms/step
# Epoch 4/50
# 9228/9228 - 14s - loss: 3.0586 - precision: 0.1047 - recall: 0.7574 - auc: 0.8418 - prc: 0.2389 - val_loss: 0.5608 - val_precision: 0.1023 - val_recall: 0.7273 - val_auc: 0.8117 - val_prc: 0.1655 - lr: 0.0100 - 14s/epoch - 2ms/step
# Epoch 5/50
# 9228/9228 - 15s - loss: 3.0029 - precision: 0.1074 - recall: 0.7598 - auc: 0.8461 - prc: 0.2420 - val_loss: 0.5020 - val_precision: 0.1146 - val_recall: 0.6902 - val_auc: 0.8172 - val_prc: 0.1937 - lr: 0.0100 - 15s/epoch - 2ms/step
# Epoch 6/50
# 9228/9228 - 15s - loss: 3.0281 - precision: 0.1065 - recall: 0.7670 - auc: 0.8468 - prc: 0.2521 - val_loss: 0.4340 - val_precision: 0.1259 - val_recall: 0.6365 - val_auc: 0.8168 - val_prc: 0.1965 - lr: 0.0100 - 15s/epoch - 2ms/step
# Epoch 7/50
# 9228/9228 - 15s - loss: 2.9888 - precision: 0.1094 - recall: 0.7656 - auc: 0.8507 - prc: 0.2514 - val_loss: 0.4358 - val_precision: 0.1272 - val_recall: 0.6243 - val_auc: 0.8151 - val_prc: 0.1940 - lr: 0.0100 - 15s/epoch - 2ms/step
# Epoch 8/50
# 9228/9228 - 15s - loss: 2.8537 - precision: 0.1160 - recall: 0.7777 - auc: 0.8614 - prc: 0.2915 - val_loss: 0.4261 - val_precision: 0.1282 - val_recall: 0.6506 - val_auc: 0.8217 - val_prc: 0.2099 - lr: 0.0030 - 15s/epoch - 2ms/step
# Epoch 9/50
# 9228/9228 - 16s - loss: 2.8380 - precision: 0.1164 - recall: 0.7808 - auc: 0.8633 - prc: 0.2934 - val_loss: 0.7015 - val_precision: 0.0914 - val_recall: 0.7791 - val_auc: 0.8211 - val_prc: 0.2103 - lr: 0.0030 - 16s/epoch - 2ms/step
# Epoch 10/50
# 9228/9228 - 15s - loss: 2.8309 - precision: 0.1170 - recall: 0.7796 - auc: 0.8640 - prc: 0.2967 - val_loss: 0.4951 - val_precision: 0.1168 - val_recall: 0.6873 - val_auc: 0.8202 - val_prc: 0.1978 - lr: 0.0030 - 15s/epoch - 2ms/step
# Epoch 11/50
# 9228/9228 - 15s - loss: 2.7900 - precision: 0.1176 - recall: 0.7862 - auc: 0.8678 - prc: 0.3089 - val_loss: 0.5662 - val_precision: 0.1053 - val_recall: 0.7258 - val_auc: 0.8204 - val_prc: 0.2041 - lr: 0.0010 - 15s/epoch - 2ms/step
# Epoch 12/50
# 9228/9228 - 16s - loss: 2.7846 - precision: 0.1181 - recall: 0.7841 - auc: 0.8683 - prc: 0.3118 - val_loss: 0.4932 - val_precision: 0.1153 - val_recall: 0.6924 - val_auc: 0.8212 - val_prc: 0.2140 - lr: 0.0010 - 16s/epoch - 2ms/step
# Epoch 13/50
# 9228/9228 - 16s - loss: 2.7989 - precision: 0.1193 - recall: 0.7821 - auc: 0.8684 - prc: 0.3122 - val_loss: 0.5186 - val_precision: 0.1115 - val_recall: 0.7083 - val_auc: 0.8220 - val_prc: 0.2168 - lr: 0.0010 - 16s/epoch - 2ms/step
# Epoch 14/50
# 9228/9228 - 17s - loss: 2.7783 - precision: 0.1199 - recall: 0.7845 - auc: 0.8690 - prc: 0.3130 - val_loss: 0.5324 - val_precision: 0.1084 - val_recall: 0.7190 - val_auc: 0.8213 - val_prc: 0.2142 - lr: 0.0010 - 17s/epoch - 2ms/step
# Epoch 15/50
# 9228/9228 - 16s - loss: 2.7808 - precision: 0.1185 - recall: 0.7849 - auc: 0.8690 - prc: 0.3123 - val_loss: 0.5083 - val_precision: 0.1134 - val_recall: 0.7027 - val_auc: 0.8217 - val_prc: 0.2172 - lr: 0.0010 - 16s/epoch - 2ms/step
# Epoch 16/50
# 9228/9228 - 17s - loss: 2.7751 - precision: 0.1198 - recall: 0.7860 - auc: 0.8696 - prc: 0.3147 - val_loss: 0.5321 - val_precision: 0.1090 - val_recall: 0.7184 - val_auc: 0.8219 - val_prc: 0.2158 - lr: 0.0010 - 17s/epoch - 2ms/step
# Epoch 17/50
# 9228/9228 - 17s - loss: 2.7810 - precision: 0.1195 - recall: 0.7852 - auc: 0.8699 - prc: 0.3145 - val_loss: 0.5040 - val_precision: 0.1158 - val_recall: 0.6885 - val_auc: 0.8213 - val_prc: 0.2153 - lr: 0.0010 - 17s/epoch - 2ms/step
# Epoch 18/50
# 9228/9228 - 17s - loss: 2.7698 - precision: 0.1210 - recall: 0.7834 - auc: 0.8699 - prc: 0.3163 - val_loss: 0.5874 - val_precision: 0.1025 - val_recall: 0.7362 - val_auc: 0.8212 - val_prc: 0.2135 - lr: 0.0010 - 17s/epoch - 2ms/step
# Epoch 19/50
# 9228/9228 - 17s - loss: 2.7871 - precision: 0.1197 - recall: 0.7849 - auc: 0.8702 - prc: 0.3197 - val_loss: 0.5083 - val_precision: 0.1150 - val_recall: 0.6975 - val_auc: 0.8216 - val_prc: 0.2147 - lr: 0.0010 - 17s/epoch - 2ms/step
# Epoch 20/50
# 9228/9228 - 18s - loss: 2.7699 - precision: 0.1202 - recall: 0.7852 - auc: 0.8701 - prc: 0.3192 - val_loss: 0.4741 - val_precision: 0.1213 - val_recall: 0.6706 - val_auc: 0.8209 - val_prc: 0.2098 - lr: 0.0010 - 18s/epoch - 2ms/step
# Epoch 21/50
# 9228/9228 - 18s - loss: 2.7649 - precision: 0.1211 - recall: 0.7842 - auc: 0.8708 - prc: 0.3217 - val_loss: 0.4876 - val_precision: 0.1176 - val_recall: 0.6869 - val_auc: 0.8215 - val_prc: 0.2089 - lr: 0.0010 - 18s/epoch - 2ms/step
# Epoch 22/50
# 9228/9228 - 18s - loss: 2.7631 - precision: 0.1206 - recall: 0.7842 - auc: 0.8708 - prc: 0.3219 - val_loss: 0.5422 - val_precision: 0.1089 - val_recall: 0.7150 - val_auc: 0.8213 - val_prc: 0.2090 - lr: 0.0010 - 18s/epoch - 2ms/step
# Epoch 23/50
# 9228/9228 - 18s - loss: 2.7575 - precision: 0.1204 - recall: 0.7880 - auc: 0.8712 - prc: 0.3217 - val_loss: 0.5313 - val_precision: 0.1110 - val_recall: 0.7092 - val_auc: 0.8220 - val_prc: 0.2161 - lr: 0.0010 - 18s/epoch - 2ms/step
# Epoch 24/50
# 9228/9228 - 19s - loss: 2.7555 - precision: 0.1210 - recall: 0.7865 - auc: 0.8715 - prc: 0.3252 - val_loss: 0.4807 - val_precision: 0.1212 - val_recall: 0.6750 - val_auc: 0.8210 - val_prc: 0.2093 - lr: 0.0010 - 19s/epoch - 2ms/step
# Epoch 25/50
# 9228/9228 - 20s - loss: 2.7641 - precision: 0.1215 - recall: 0.7850 - auc: 0.8715 - prc: 0.3250 - val_loss: 0.5639 - val_precision: 0.1065 - val_recall: 0.7246 - val_auc: 0.8209 - val_prc: 0.2069 - lr: 0.0010 - 20s/epoch - 2ms/step
# Epoch 26/50
# 9228/9228 - 19s - loss: 2.7514 - precision: 0.1215 - recall: 0.7867 - auc: 0.8720 - prc: 0.3261 - val_loss: 0.5385 - val_precision: 0.1094 - val_recall: 0.7146 - val_auc: 0.8212 - val_prc: 0.2137 - lr: 0.0010 - 19s/epoch - 2ms/step
# Epoch 27/50
# 9228/9228 - 19s - loss: 2.7517 - precision: 0.1215 - recall: 0.7848 - auc: 0.8720 - prc: 0.3283 - val_loss: 0.5276 - val_precision: 0.1103 - val_recall: 0.7159 - val_auc: 0.8222 - val_prc: 0.2184 - lr: 0.0010 - 19s/epoch - 2ms/step
# Epoch 28/50
# 9228/9228 - 20s - loss: 2.7488 - precision: 0.1212 - recall: 0.7879 - auc: 0.8722 - prc: 0.3295 - val_loss: 0.4934 - val_precision: 0.1154 - val_recall: 0.6961 - val_auc: 0.8223 - val_prc: 0.2175 - lr: 0.0010 - 20s/epoch - 2ms/step
# Epoch 29/50
# 9228/9228 - 20s - loss: 2.7480 - precision: 0.1215 - recall: 0.7913 - auc: 0.8725 - prc: 0.3283 - val_loss: 0.4895 - val_precision: 0.1164 - val_recall: 0.6928 - val_auc: 0.8211 - val_prc: 0.2146 - lr: 0.0010 - 20s/epoch - 2ms/step
# Epoch 30/50
# 9228/9228 - 20s - loss: 2.7419 - precision: 0.1214 - recall: 0.7923 - auc: 0.8726 - prc: 0.3312 - val_loss: 0.4287 - val_precision: 0.1308 - val_recall: 0.6446 - val_auc: 0.8204 - val_prc: 0.2092 - lr: 0.0010 - 20s/epoch - 2ms/step
# Epoch 31/50
# 9228/9228 - 20s - loss: 2.7456 - precision: 0.1225 - recall: 0.7888 - auc: 0.8727 - prc: 0.3302 - val_loss: 0.5421 - val_precision: 0.1082 - val_recall: 0.7159 - val_auc: 0.8193 - val_prc: 0.2061 - lr: 0.0010 - 20s/epoch - 2ms/step
# Epoch 32/50
# 9228/9228 - 20s - loss: 2.7372 - precision: 0.1225 - recall: 0.7874 - auc: 0.8733 - prc: 0.3331 - val_loss: 0.5662 - val_precision: 0.1065 - val_recall: 0.7266 - val_auc: 0.8217 - val_prc: 0.2162 - lr: 0.0010 - 20s/epoch - 2ms/step
# Epoch 33/50
# 9228/9228 - 19s - loss: 2.7411 - precision: 0.1220 - recall: 0.7876 - auc: 0.8732 - prc: 0.3335 - val_loss: 0.4628 - val_precision: 0.1240 - val_recall: 0.6633 - val_auc: 0.8189 - val_prc: 0.2060 - lr: 0.0010 - 19s/epoch - 2ms/step
# Epoch 34/50
# 9228/9228 - 20s - loss: 2.7337 - precision: 0.1225 - recall: 0.7915 - auc: 0.8737 - prc: 0.3341 - val_loss: 0.4969 - val_precision: 0.1169 - val_recall: 0.6922 - val_auc: 0.8205 - val_prc: 0.2091 - lr: 0.0010 - 20s/epoch - 2ms/step
# Epoch 35/50
# 9228/9228 - 20s - loss: 2.7352 - precision: 0.1224 - recall: 0.7908 - auc: 0.8740 - prc: 0.3351 - val_loss: 0.4963 - val_precision: 0.1180 - val_recall: 0.6869 - val_auc: 0.8196 - val_prc: 0.2078 - lr: 0.0010 - 20s/epoch - 2ms/step
# Epoch 36/50
# 9228/9228 - 19s - loss: 2.7279 - precision: 0.1228 - recall: 0.7900 - auc: 0.8741 - prc: 0.3367 - val_loss: 0.5592 - val_precision: 0.1091 - val_recall: 0.7166 - val_auc: 0.8208 - val_prc: 0.2213 - lr: 0.0010 - 19s/epoch - 2ms/step
# Epoch 37/50
# 9228/9228 - 20s - loss: 2.7277 - precision: 0.1229 - recall: 0.7893 - auc: 0.8741 - prc: 0.3342 - val_loss: 0.4563 - val_precision: 0.1245 - val_recall: 0.6650 - val_auc: 0.8208 - val_prc: 0.2193 - lr: 0.0010 - 20s/epoch - 2ms/step
# Epoch 38/50
# 9228/9228 - 20s - loss: 2.7320 - precision: 0.1226 - recall: 0.7915 - auc: 0.8742 - prc: 0.3354 - val_loss: 0.5293 - val_precision: 0.1125 - val_recall: 0.7054 - val_auc: 0.8195 - val_prc: 0.2139 - lr: 0.0010 - 20s/epoch - 2ms/step
# Epoch 39/50
# 9228/9228 - 19s - loss: 2.7250 - precision: 0.1241 - recall: 0.7922 - auc: 0.8744 - prc: 0.3370 - val_loss: 0.5290 - val_precision: 0.1109 - val_recall: 0.7104 - val_auc: 0.8205 - val_prc: 0.2150 - lr: 0.0010 - 19s/epoch - 2ms/step
# Epoch 40/50
# 9228/9228 - 21s - loss: 2.7203 - precision: 0.1227 - recall: 0.7899 - auc: 0.8749 - prc: 0.3384 - val_loss: 0.5134 - val_precision: 0.1149 - val_recall: 0.6978 - val_auc: 0.8201 - val_prc: 0.2167 - lr: 0.0010 - 21s/epoch - 2ms/step
# Epoch 41/50
# 9228/9228 - 19s - loss: 2.7223 - precision: 0.1233 - recall: 0.7902 - auc: 0.8748 - prc: 0.3382 - val_loss: 0.5048 - val_precision: 0.1147 - val_recall: 0.6993 - val_auc: 0.8208 - val_prc: 0.2168 - lr: 0.0010 - 19s/epoch - 2ms/step
# Epoch 42/50
# 9228/9228 - 21s - loss: 2.7181 - precision: 0.1230 - recall: 0.7924 - auc: 0.8749 - prc: 0.3393 - val_loss: 0.4989 - val_precision: 0.1150 - val_recall: 0.6969 - val_auc: 0.8200 - val_prc: 0.2190 - lr: 0.0010 - 21s/epoch - 2ms/step
# Epoch 43/50
# 9228/9228 - 20s - loss: 2.7208 - precision: 0.1235 - recall: 0.7917 - auc: 0.8747 - prc: 0.3409 - val_loss: 0.4787 - val_precision: 0.1211 - val_recall: 0.6764 - val_auc: 0.8202 - val_prc: 0.2232 - lr: 0.0010 - 20s/epoch - 2ms/step
# Epoch 00043: early stopping

# %%
plt.plot(history_new.epoch, history_new.history['loss'], c='g');      # green - training loss
plt.plot(history_new.epoch, history_new.history['val_loss'], c='b');  # blue - test loss

# %%
pred_model_nn2 = model_nn2.predict(X_test)

# %%
np.round(pred_model_nn2).sum()/len(pred_model_nn)
# Out:
# 0.20365089579029363

# %%
plot_cmatrix(y_test, np.round(pred_model_nn2))
# Out:
# ***Confusion Matrix***
#           Predicted notFraud  Predicted isFraud
# notFraud              231653              52848
# isFraud                 3485               7284
# Scores:
# ------------------------------
#
# Fraud recall:   0.68
# Fraud precision: 0.12

# %%
table = {'Model': 'CNN2-rlr'}

table['CV mean ROC-AUC'] = 'N/A'
table['ROC-AUC-train'] = roc_auc_score(y_train, model_nn2.predict(X_train))
table['ROC-AUC-test'] = roc_auc_score(y_test, model_nn2.predict(X_test))
table['Precision'] = precision_score(y_test, np.round(pred_model_nn2))
table['Recall'] = recall_score(y_test,np.round(pred_model_nn2))
table
# Out:
# {'Model': 'CNN2-rlr',
#  'CV mean ROC-AUC': 'N/A',
#  'ROC-AUC-train': 0.8773237798574737,
#  'ROC-AUC-test': 0.8202745229182257,
#  'Precision': 0.12113350628617042,
#  'Recall': 0.6763859225554834}

# %%
scoring_table.append(table)
scoring_table
# Out:
# [{'Model': 'LGBM_enc1',
#   'CV mean ROC-AUC': 0.9242801082771159,
#   'ROC-AUC-train': 0.9254746112929142,
#   'ROC-AUC-test': 0.8988196375723794,
#   'Precision': 0.8115737473535639,
#   'Recall': 0.32036400780016716},
#  {'Model': 'LGBM_enc2_W',
#   'CV mean ROC-AUC': 0.9064810343220386,
#   'ROC-AUC-train': 0.9041648974402643,
#   'ROC-AUC-test': 0.8738520789626306,
#   'Precision': 0.36795556505020294,
#   'Recall': 0.5133830104321908},
#  {'Model': 'LGBM_enc32',
#   'CV mean ROC-AUC': 0.9239109462254117,
#   'ROC-AUC-train': 0.925275221536445,
#   'ROC-AUC-test': 0.9001890538059367,
#   'Precision': 0.8185053380782918,
#   'Recall': 0.32036400780016716},
#  {'Model': 'RF1',
#   'CV mean ROC-AUC': 0.8965494117221681,
#   'ROC-AUC-train': 0.9763664284217599,
#   'ROC-AUC-test': 0.8866158364349617,
#   'Precision': 0.8433351035581519,
#   'Recall': 0.25926530612244897},
#  {'Model': 'CNN2-rlr',
#   'CV mean ROC-AUC': 'N/A',
#   'ROC-AUC-train': 0.8773237798574737,
#   'ROC-AUC-test': 0.8202745229182257,
#   'Precision': 0.12113350628617042,
#   'Recall': 0.6763859225554834}]

# %%
# table1
# Out:
# {'Model': 'CNN1',
#  'CV mean ROC-AUC': 'N/A',
#  'ROC-AUC-train': 0.9156116515089099,
#  'ROC-AUC-test': 0.8217454628760483,
#  'Precision': 0.10535364117441642,
#  'Recall': 0.7283870368650757}

# %%
# model_nn2.save('../Models/model_nn2.sav')
# model_nn2_loaded = keras.models.load_model('../Models/model_nn2.sav')

# %%
[9,1]+[4,5]
# Out:
# [9, 1, 4, 5]

# %%
#copy paste the scoring table from the previous notebook and add it to this one
new_table = [{'Model': 'LGBM1',
  'CV mean ROC-AUC': 0.9237209868128602,
  'ROC-AUC-train': 0.9249212975379344,
  'ROC-AUC-test': 0.8878715164195475,
  'Precision': 0.8689538807649044,
  'Recall': 0.28693472002971493},
 {'Model': 'LGBM2',
  'CV mean ROC-AUC': 0.9138002901461071,
  'ROC-AUC-train': 0.911785761942706,
  'ROC-AUC-test': 0.8718071234245038,
  'Precision': 0.8643410852713178,
  'Recall': 0.2691986256848361},
 {'Model': 'LGBM3-wght',
  'CV mean ROC-AUC': 0.9006955440640529,
  'ROC-AUC-train': 0.8946079476688565,
  'ROC-AUC-test': 0.8962648396644237,
  'Precision': 0.4997057092407298,
  'Recall': 0.49941176470588233}] + scoring_table

# %%
models = pd.DataFrame(new_table).replace('N/A', np.nan).round(3)
models
# Out:
#          Model  CV mean ROC-AUC  ROC-AUC-train  ROC-AUC-test  Precision  \
# 0        LGBM1            0.924          0.925         0.888      0.869
# 1        LGBM2            0.914          0.912         0.872      0.864
# 2   LGBM3-wght            0.901          0.895         0.896      0.500
# 3    LGBM_enc1            0.924          0.925         0.899      0.812
# 4  LGBM_enc2_W            0.906          0.904         0.874      0.368
# 5   LGBM_enc32            0.924          0.925         0.900      0.819
# 6          RF1            0.897          0.976         0.887      0.843
# 7     CNN2-rlr              NaN          0.877         0.820      0.121
#
#    Recall
# 0   0.287
# 1   0.269
# 2   0.499
# 3   0.320
# 4   0.513
# 5   0.320
# 6   0.259
# 7   0.676

# %%
models.to_csv('../datasets/models_tablefinal.csv', index=False)

# %%
def highlight(s, value, column):
    """ the function takes a df, a value and a column and highlights 
    rows in the df where the column cell equals the value
    """
    is_max = pd.Series(data=False, index=s.index)
    is_max[column] = (s.loc[column] == value)
    return ['background-color: lightsalmon' if is_max.any() else '' for v in is_max]

# %%
models.style.apply(highlight, value=0.899, column=['ROC-AUC-test'], axis=1)
# Out:
# <style  type="text/css" >
# #T_53fb2_row3_col0,#T_53fb2_row3_col1,#T_53fb2_row3_col2,#T_53fb2_row3_col3,#T_53fb2_row3_col4,#T_53fb2_row3_col5{
#             background-color:  lightsalmon;
#         }</style><table id="T_53fb2_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >CV mean ROC-AUC</th>        <th class="col_heading level0 col2" >ROC-AUC-train</th>        <th class="col_heading level0 col3" >ROC-AUC-test</th>        <th class="col_heading level0 col4" >Precision</th>        <th class="col_heading level0 col5" >Recall</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_53fb2_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_53fb2_row0_col0" class="data row0 col0" >LGBM1</td>
#                         <td id="T_53fb2_row0_col1" class="data row0 col1" >0.924000</td>
#                         <td id="T_53fb2_row0_col2" class="data row0 col2" >0.925000</td>
#                         <td id="T_53fb2_row0_col3" class="data row0 col3" >0.888000</td>
#                         <td id="T_53fb2_row0_col4" class="data row0 col4" >0.869000</td>
#                         <td id="T_53fb2_row0_col5" class="data row0 col5" >0.287000</td>
#             </tr>
#             <tr>
#                         <th id="T_53fb2_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_53fb2_row1_col0" class="data row1 col0" >LGBM2</td>
#                         <td id="T_53fb2_row1_col1" class="data row1 col1" >0.914000</td>
#                         <td id="T_53fb2_row1_col2" class="data row1 col2" >0.912000</td>
#                         <td id="T_53fb2_row1_col3" class="data row1 col3" >0.872000</td>
#                         <td id="T_53fb2_row1_col4" class="data row1 col4" >0.864000</td>
#                         <td id="T_53fb2_row1_col5" class="data row1 col5" >0.269000</td>
#             </tr>
#             <tr>
#                         <th id="T_53fb2_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_53fb2_row2_col0" class="data row2 col0" >LGBM3-wght</td>
#                         <td id="T_53fb2_row2_col1" class="data row2 col1" >0.901000</td>
#                         <td id="T_53fb2_row2_col2" class="data row2 col2" >0.895000</td>
#                         <td id="T_53fb2_row2_col3" class="data row2 col3" >0.896000</td>
#                         <td id="T_53fb2_row2_col4" class="data row2 col4" >0.500000</td>
#                         <td id="T_53fb2_row2_col5" class="data row2 col5" >0.499000</td>
#             </tr>
#             <tr>
#                         <th id="T_53fb2_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_53fb2_row3_col0" class="data row3 col0" >LGBM_enc1</td>
#                         <td id="T_53fb2_row3_col1" class="data row3 col1" >0.924000</td>
#                         <td id="T_53fb2_row3_col2" class="data row3 col2" >0.925000</td>
#                         <td id="T_53fb2_row3_col3" class="data row3 col3" >0.899000</td>
#                         <td id="T_53fb2_row3_col4" class="data row3 col4" >0.812000</td>
#                         <td id="T_53fb2_row3_col5" class="data row3 col5" >0.320000</td>
#             </tr>
#             <tr>
#                         <th id="T_53fb2_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_53fb2_row4_col0" class="data row4 col0" >LGBM_enc2_W</td>
#                         <td id="T_53fb2_row4_col1" class="data row4 col1" >0.906000</td>
#                         <td id="T_53fb2_row4_col2" class="data row4 col2" >0.904000</td>
#                         <td id="T_53fb2_row4_col3" class="data row4 col3" >0.874000</td>
#                         <td id="T_53fb2_row4_col4" class="data row4 col4" >0.368000</td>
#                         <td id="T_53fb2_row4_col5" class="data row4 col5" >0.513000</td>
#             </tr>
#             <tr>
#                         <th id="T_53fb2_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_53fb2_row5_col0" class="data row5 col0" >LGBM_enc32</td>
#                         <td id="T_53fb2_row5_col1" class="data row5 col1" >0.924000</td>
#                         <td id="T_53fb2_row5_col2" class="data row5 col2" >0.925000</td>
#                         <td id="T_53fb2_row5_col3" class="data row5 col3" >0.900000</td>
#                         <td id="T_53fb2_row5_col4" class="data row5 col4" >0.819000</td>
#                         <td id="T_53fb2_row5_col5" class="data row5 col5" >0.320000</td>
#             </tr>
#             <tr>
#                         <th id="T_53fb2_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_53fb2_row6_col0" class="data row6 col0" >RF1</td>
#                         <td id="T_53fb2_row6_col1" class="data row6 col1" >0.897000</td>
#                         <td id="T_53fb2_row6_col2" class="data row6 col2" >0.976000</td>
#                         <td id="T_53fb2_row6_col3" class="data row6 col3" >0.887000</td>
#                         <td id="T_53fb2_row6_col4" class="data row6 col4" >0.843000</td>
#                         <td id="T_53fb2_row6_col5" class="data row6 col5" >0.259000</td>
#             </tr>
#             <tr>
#                         <th id="T_53fb2_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_53fb2_row7_col0" class="data row7 col0" >CNN2-rlr</td>
#                         <td id="T_53fb2_row7_col1" class="data row7 col1" >nan</td>
#                         <td id="T_53fb2_row7_col2" class="data row7 col2" >0.877000</td>
#                         <td id="T_53fb2_row7_col3" class="data row7 col3" >0.820000</td>
#                         <td id="T_53fb2_row7_col4" class="data row7 col4" >0.121000</td>
#                         <td id="T_53fb2_row7_col5" class="data row7 col5" >0.676000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# <a id = '7.0'><a/>
# ### 7.0 Conclusions
# * [Back To Top](#Content)

# %% [markdown]
# - As we can see in the table above, many of the models we ran have a similar ROC-AUC score in the range of 0.88-0.90. Of course, when it comes to issues as important at credit card fraud, every percentage point matters, and in a dataset as unbalanced as this one, where only 3.5% of rows are fraud, every little improvement is hard to come by.
#
# - The first 3 models (0, 1, and 2) are run on a dataset without encoded categorical features and without filled-in null values. That was done because the model used was Light GBM which handles nulls and categorical columns internally better than if it had been undertaken by us
#
# - the results of the model 2 (LGBM3-wght) are a fluke. Firstly, it test score is higher than its train score which doesn't make any sense. Secondly, we added weights to counter the unbalanced data which should result in higher recall and lower ROC-AUC, as focusing on positive (fraud) outcome uncovers more of them at the expense of overall test metrics. Instead the ROC-AUC went up, counter-intuitively. Normally we would reshuffle the train and test data to double-check such results, but since chronological data does not get shuffled, we couldn't do that.
#
# - After encoding (models 3 and up) we could run different classifiers (RF, NN) in addition to re-running the LGBM. The results of LGBM are generally better after encoding (dummy and hash) than before. The conclusions we can draw from that are that: splitting key features with low cardinality increased the predictive power of our model, as expected. Moreover, we can conclude that hash encoding,  by 'compacting' many high-cardinality features into only 8 columns managed to preserve predictive power of the model. That is a laudable achievement for our hash-encoder as it gives us a way to model categorical data without exploding the size of our dataset.
#
# - model 5 - LGBM with a 32-bit hash encoding (rather than previously used 8-bit one) did not result in any improvement, despite the additional 24 columns of hashing space. Hence, the model 3 is preferred as it's exactly the same as model 5, but it takes up 24 fewer columns
#
# - model 7, the Keras Neural Network Classifier, while not ideally suited for unbalanced classification, managed to produce a model with the highest recall score of 0.676 - catching more than 2/3 of fraudulent transaction. Industry standard is 50%, so that's quite good. The downside is that the precision is quite low, so many legitimate transactions will get delayed or declined.
#
#
# **WAY FORWARD**
#
# - these models took an average of less than an hour to run on a laptop with only 4 cores. That is amazing when you consider we started out with a dataset with 500k rows and 400+ columns. It would be interesting to compare the results of our model number 3 to a model run on the entire dataset (which would end up having more than a 1000 columns once categorical variable are encoded). Would there be a noticeable jump in performance? By how much?
#
# -  use behavioral analytics to identify bad actors across a range of online misconducts including counterfeit products, fake reviews, malware and illegal content. By casting a wider net, we can learn more about patterns common to fraud. This would result in a diversified new set of features for machines to train on.
