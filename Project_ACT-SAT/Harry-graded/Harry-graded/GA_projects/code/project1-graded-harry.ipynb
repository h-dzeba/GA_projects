# %% [markdown]
# <div style="border: 1px solid thistle; padding: 5px 20px 10px 20px;">
#     <h2><font color = "77658f" style=";"> Feedback </font></h2><br>
#     <font color = "77658f"> • Project Organisation - No issues with project organisation.  <br> • Clarity of Message - Message has been clearly put across. Consider including more markdowns in the earlier sections of the project instead of using comments all the time. <br> • Python Syntax and Control Flow - Has demonstrated mastery of writing functions evident from the custom subplot functions created. <br> • Data Cleaning and EDA - Data cleaning and EDA performed was performed well with clear explanations on steps taken. <br> • Visualisations - Visualizations are generally well done with a focus on details. Good to see the use of arrows in plots to highlight points of interest. <br> • Research and Conceptual Understanding - Outside research need not be limited to data sources, and also could include articles that support some of your findings. <br> • Presentation - Clear, confident and convincing <br>  <br><br>
#         • Project Organisation: <b>2</b> <br>
#         • Clarity of Message: <b>2</b> <br>
#         • Python Syntax and Control Flow: <b>3</b><br>
#         • Data Cleaning and EDA: <b>3</b><br>
#         • Visualisations: <b>3</b><br>
#         • Research and Conceptual Understanding: <b>2</b><br>
#         • Presentation: <b>3</b><br>
#     </font>
# </div>

# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# *2019 College Admissions Cheating Scandal brought into focus the lengths that high-income parents will go to in order to game the system of standardized tests dominated by ACT and SAT. While not as egregious as such cases of outright cheating, economic bias is something that both tests have been getting accused of for quite some time, and as a result, some universities are eliminating or making optional their requirement to have at least one of the tests submitted as part of admission process.
# In this project we are hired by ACT, Inc to investigate reports that ACT tests exhibit more economic bias than its rival SAT, and additionally, to isolate the top performers among low-income districts to learn from them and to propose ways to eliminate or at least reduce the economic bias going forward.*

# %% [markdown]
# > <font size = 3 color = "crimson"> Consider starting the last sentence on a new line.</font>

# %% [markdown]
# <a id = 'Content'><a/>
# ### Contents:
# - [1.0 Background](#1.0)
#     - [1.1 Coding Challenges](#1.1)
# - [2.0 Data Import & Cleaning](#2.0)
#     - [2.1 CAL2019 SAT cleanup](#2.1)
#     - [2.2 CAL2019 ACT cleanup](#2.2)
#     - [2.3 CAL Income Table Cleanup](#2.3)
#     - [2.4 USA 2019 ACT and SAT cleanup](#2.4)
#     - [2.5 USA income table cleanup](#2.5)
#     - [2.6 Quantile cuts and final cleanup](#2.6)
#     - [2.7 Data Dictionary](#2.7)
# - [3.0 Exploratory Data Analysis](#3.0)
# - [4.0 Data Visualization](#4.0)
# - [5.0 Conclusions and Recommendations](#5.0)

# %% [markdown]
# <a id = '1.0'><a/>
# ### 1.0 Background
# * [Back To Top](#Content)

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# **To-Do:** *Fill out this cell (or edit the above cell) with any other background or information that is necessary for your problem statement.*

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# **To-Do:** *Fill out this cell with the datasets you will use for your analysis. Write a brief description of the contents for each dataset that you choose.*
#
# * [`act_2019_ca.csv`](../data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2019_ca.csv`](../data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`act_2019.csv`](../data/act_2019.csv): 2019 ACT Scores by State
# * [`sat_2019.csv`](../data/sat_2019.csv): 2019 SAT Scores by State

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# **To-Do:** *Fill out this cell with outside research or any additional background information that will support your analysis.*
#
# * [`ACSST1Y2018.csv`](../data/ACSST1Y2018.csv): 2018 Household income by State
# * [`Cal_Income_by_county_(2014).csv`](../data/Cal_Income_by_county_(2014-18).csv): 2018 California Household income by county
#
# https://magoosh.com/hs/sat/states-that-require-the-act-or-sat/ : list of states where taking one or either test is mandatory
#
# https://www.redding.com/story/news/2021/11/10/central-valley-high-school-dual-enrollment-college-credit-university-courses/6358940001/ : report on innovative school programs from Shasta County, CA
#
#  https://in.chalkbeat.org/2018/9/4/21105695/indiana-officials-didn-t-have-to-go-far-to-find-a-new-model-for-improving-schools : article on new model for assessing schools in the state of Indiana

# %% [markdown]
# <a id = '1.1'><a/>
# ### 1.1 Coding Challenges
# * [Back To Top](#Content)
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# a list
sample = [3, 56, 12, 3.77, 22, -12]

# %%
# mean function

def mean(lst):
    return sum(lst)/len(lst)
# the instructions say "do not use any mean methods",
# but i hope using sum and len functions is ok

# %% [markdown]
# > <font size = 3 color = "crimson"> Your code above is fine. You should be able to do it even if you cannot use any built-in functions too!</font>

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
def stdev(lst):
    total = 0
    for i in lst:
        total += (i - mean(lst))**2
    return (total/len(lst))**0.5

# %%
print(round(stdev(sample),2))
# Out:
# 21.34

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
def convert_percent(percent):
    try:
        decimal = float(percent.rstrip('%'))
        return decimal/100
    except: 
        return

# %%
#test by Ryan
import pandas as pd
a_list = ['5%','100.5%','75%','99',98]
a_df = pd.DataFrame({'a_col':a_list})
a_df['a_col'].map(convert_percent)
# Out:
# 0    0.050
# 1    1.005
# 2    0.750
# 3    0.990
# 4      NaN
# Name: a_col, dtype: float64

# %% [markdown]
# > <font size = 3 color = "crimson"> Good work for the code review section</font>

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports:
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# > <font size = 3 color = "crimson"> Consider including sns.set() to apply default seaborn theme </font>

# %% [markdown]
# <a id = '2.0'><a/>
# ## 2.0 Data Import and Cleaning
# * [Back To Top](#Content)

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %% [markdown]
# <a id = '2.1'><a/>
# # 2.1 CAL2019 SAT cleanup
# * [Back To Top](#Content)

# %% [markdown]
# ### Loading up 6 files: 4 of them part of the Project1 assignment, and 2 external files related to household incomes

# %%
# Code:
CAsat = pd.read_csv('../data/sat_2019_ca.csv')
CAact = pd.read_csv('../data/act_2019_ca.csv')
CAincome = pd.read_csv('../data/Cal_Income_by_county_(2014).csv')
SAT19 = pd.read_csv('../data/sat_2019.csv')
ACT19 = pd.read_csv('../data/act_2019.csv')
USincome = pd.read_csv('../data/ACSST1Y2018.csv')

# %% [markdown]
# > <font size = 3 color = "crimson"> Good use of relative path when reading in csv files</font>

# %%
pd.set_option("display.max_columns", 40)

# %% [markdown]
# ### Dataframe display, shape and info

# %%
print(CAsat.shape)
CAsat.head()
# Out:
# (2579, 25)
#             CDS  CCode   CDCode    SCode RType                    SName  \
# 0  6.615980e+12      6   661598   630046     S  Colusa Alternative Home
# 1  6.616060e+12      6   661606   634758     S          Maxwell Sr High
# 2  1.964730e+13     19  1964733  1930924     S      Belmont Senior High
# 3  1.964730e+13     19  1964733  1931476     S  Canoga Park Senior High
# 4  1.964730e+13     19  1964733  1931856     S     Whitman Continuation
#
#                  DName        CName  Enroll12  NumTSTTakr12 NumERWBenchmark12  \
# 0       Colusa Unified       Colusa        18             0               NaN
# 1      Maxwell Unified       Colusa        29            10                 *
# 2  Los Angeles Unified  Los Angeles       206           102                31
# 3  Los Angeles Unified  Los Angeles       227           113                54
# 4  Los Angeles Unified  Los Angeles        18            14                 *
#
# ...

# %%
display(CAsat.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2579 entries, 0 to 2578
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CDS                    2579 non-null   float64
#  1   CCode                  2579 non-null   int64
#  2   CDCode                 2579 non-null   int64
#  3   SCode                  2579 non-null   int64
#  4   RType                  2579 non-null   object
#  5   SName                  1982 non-null   object
#  6   DName                  2521 non-null   object
#  7   CName                  2579 non-null   object
#  8   Enroll12               2579 non-null   int64
#  9   NumTSTTakr12           2579 non-null   int64
#  10  NumERWBenchmark12      2304 non-null   object
#  11  PctERWBenchmark12      2304 non-null   object
#  12  NumMathBenchmark12     2304 non-null   object
#  13  PctMathBenchmark12     2304 non-null   object
# ...

# %% [markdown]
# ### Dropping and Renaming columns

# %%
# make column names lowercase first
CAsat.columns = CAsat.columns.str.lower()

# %%
#drop those 2 columns, plus those not needed in analysis like certain codes and columns 
# related to year 11 students. 
drops = [ 'year', 'cds', 'cdcode', 'scode', 'numtsttakr11',\
        'totnumbothbenchmark11', 'numerwbenchmark11', 'pctmathbenchmark11',
        'enroll11', 'pcterwbenchmark11', 'nummathbenchmark11', 'pctbothbenchmark11']

CAsat.drop(drops, axis=1, inplace=True)

# %%
print(CAsat.shape)
CAsat.head()
# Out:
# (2579, 13)
#    ccode rtype                    sname                dname        cname  \
# 0      6     S  Colusa Alternative Home       Colusa Unified       Colusa
# 1      6     S          Maxwell Sr High      Maxwell Unified       Colusa
# 2     19     S      Belmont Senior High  Los Angeles Unified  Los Angeles
# 3     19     S  Canoga Park Senior High  Los Angeles Unified  Los Angeles
# 4     19     S     Whitman Continuation  Los Angeles Unified  Los Angeles
#
#    enroll12  numtsttakr12 numerwbenchmark12 pcterwbenchmark12  \
# 0        18             0               NaN               NaN
# 1        29            10                 *                 *
# 2       206           102                31             30.39
# 3       227           113                54             47.79
# 4        18            14                 *                 *
#
#   nummathbenchmark12 pctmathbenchmark12 totnumbothbenchmark12  \
# 0                NaN                NaN                   NaN
# ...

# %% [markdown]
# ### Check the nulls.

# %%
CAsat.isnull().sum()
# Out:
# ccode                      0
# rtype                      0
# sname                    597
# dname                     58
# cname                      0
# enroll12                   0
# numtsttakr12               0
# numerwbenchmark12        275
# pcterwbenchmark12        275
# nummathbenchmark12       275
# pctmathbenchmark12       275
# totnumbothbenchmark12    275
# pctbothbenchmark12       275
# dtype: int64

# %%
# first check the 857 rows where there are no scores

CAsat[CAsat['numerwbenchmark12'].isnull()].head()
# Out:
#     ccode rtype                             sname                    dname  \
# 0       6     S           Colusa Alternative Home           Colusa Unified
# 12     15     S       Abraham Lincoln Alternative    Southern Kern Unified
# 19     10     S            Enterprise Alternative           Clovis Unified
# 36     37     S  Diego Valley East Public Charter  Julian Union Elementary
# 43     34     S     Las Flores High (Alternative)        Elk Grove Unified
#
#          cname  enroll12  numtsttakr12 numerwbenchmark12 pcterwbenchmark12  \
# 0       Colusa        18             0               NaN               NaN
# 12        Kern        18             0               NaN               NaN
# 19      Fresno        18             0               NaN               NaN
# 36   San Diego        78             0               NaN               NaN
# 43  Sacramento        64             0               NaN               NaN
#
# ...

# %%
# in the previous cell, it appears that all the rows are empty because there were very few
# test-takers. Check if there are any empty rows with more than 15 test-takers

CAsat[(CAsat['numerwbenchmark12'].isnull()) & (CAsat['numtsttakr12'] >15)].head()
# Out:
# Empty DataFrame
# Columns: [ccode, rtype, sname, dname, cname, enroll12, numtsttakr12, numerwbenchmark12, pcterwbenchmark12, nummathbenchmark12, pctmathbenchmark12, totnumbothbenchmark12, pctbothbenchmark12]
# Index: []

# %%
# there are no results so the all the nulls come from tiny schools with a small
# number of test-takers. the rows will be removed later in the coding process

#next check if all the nulls in the sname colum come from the rows that are 'C' or 'D' rtype
CAsat[(CAsat['sname'].isnull()) & (CAsat['rtype'] == 'S')].head()
# Out:
# Empty DataFrame
# Columns: [ccode, rtype, sname, dname, cname, enroll12, numtsttakr12, numerwbenchmark12, pcterwbenchmark12, nummathbenchmark12, pctmathbenchmark12, totnumbothbenchmark12, pctbothbenchmark12]
# Index: []

# %%
# since the previous command gives no results, all the nulls in sname (school name) column
# are from county and district rows, which makes sense, since those rows don't contain schools.
# leave them in the dataframe

# %% [markdown]
# ### Investigate incorrect data types, clean up & change numeric columns to float

# %%
# next investigate why columns with 'benchmark' in them are objects and not floats
# obviously, they must have some non-numeric elements
CAsat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2579 entries, 0 to 2578
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ccode                  2579 non-null   int64
#  1   rtype                  2579 non-null   object
#  2   sname                  1982 non-null   object
#  3   dname                  2521 non-null   object
#  4   cname                  2579 non-null   object
#  5   enroll12               2579 non-null   int64
#  6   numtsttakr12           2579 non-null   int64
#  7   numerwbenchmark12      2304 non-null   object
#  8   pcterwbenchmark12      2304 non-null   object
#  9   nummathbenchmark12     2304 non-null   object
#  10  pctmathbenchmark12     2304 non-null   object
#  11  totnumbothbenchmark12  2304 non-null   object
#  12  pctbothbenchmark12     2304 non-null   object
# dtypes: int64(3), object(10)
# memory usage: 262.1+ KB

# %%
# the dataframe has many '*'.
# choose one column to investigate deeper and learn from. check again if '*' appears only
# in rows with a small number of test-takers
CAsat[(CAsat['numerwbenchmark12'] == '*') & (CAsat['numtsttakr12'] >15)].head()
# Out:
# Empty DataFrame
# Columns: [ccode, rtype, sname, dname, cname, enroll12, numtsttakr12, numerwbenchmark12, pcterwbenchmark12, nummathbenchmark12, pctmathbenchmark12, totnumbothbenchmark12, pctbothbenchmark12]
# Index: []

# %%
# no results so, our presumption from the last cell is true. replace '*' with nan
CAsat.replace('*',np.nan, inplace= True)

# now convert cleaned columns to float
for col in CAsat.columns:
    if 'benchmark' in col:
        CAsat[col] = CAsat[col].astype(float, errors = 'ignore')
        
print(CAsat.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2579 entries, 0 to 2578
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ccode                  2579 non-null   int64
#  1   rtype                  2579 non-null   object
#  2   sname                  1982 non-null   object
#  3   dname                  2521 non-null   object
#  4   cname                  2579 non-null   object
#  5   enroll12               2579 non-null   int64
#  6   numtsttakr12           2579 non-null   int64
#  7   numerwbenchmark12      1722 non-null   float64
#  8   pcterwbenchmark12      1722 non-null   float64
#  9   nummathbenchmark12     1722 non-null   float64
#  10  pctmathbenchmark12     1722 non-null   float64
#  11  totnumbothbenchmark12  1722 non-null   float64
#  12  pctbothbenchmark12     1722 non-null   float64
# dtypes: float64(6), int64(3), object(4)
# memory usage: 262.1+ KB
# None

# %%
#important columns to focus on: ccode and cname (county code and name),
# and pctbothbenchmark12 (percent of college-worthy test-takers )
print(CAsat['cname'].nunique())
print(CAsat['cname'].value_counts())
# Out:
# 59
# Los Angeles            548
# San Diego              196
# San Bernardino         132
# Riverside              125
# Orange                 119
# Alameda                 94
# Sacramento              92
# Fresno                  88
# Santa Clara             81
# Contra Costa            63
# San Joaquin             61
# Kern                    58
# Stanislaus              50
# Sonoma                  50
# Tulare                  48
# Ventura                 47
# Santa Barbara           38
# Monterey                37
# San Mateo               36
# Placer                  34
# Mendocino               31
# Butte                   27
# Santa Cruz              27
# Shasta                  27
# Merced                  27
# Humboldt                27
# San Francisco           26
# Solano                  26
# San Luis Obispo         25
# Sutter                  23
# Madera                  22
# Imperial                20
# Kings                   19
# Marin                   18
# ...

# %%
# there are 59 values, but only 58 counties in CA. Scanning down the list, the outlier is
# obviously 'State of California'. Let's check it out
CAsat[CAsat['cname'] == 'State of California']
# Out:
#       ccode rtype                sname                dname  \
# 2036      0     X  State of California  State of California
#
#                     cname  enroll12  numtsttakr12  numerwbenchmark12  \
# 2036  State of California    489650        170411           116500.0
#
#       pcterwbenchmark12  nummathbenchmark12  pctmathbenchmark12  \
# 2036              68.36             81551.0               47.86
#
#       totnumbothbenchmark12  pctbothbenchmark12
# 2036                77178.0               45.29

# %% [markdown]
# ### drop rows as needed

# %%
# 'California' it a cumalative row, so it needs to be taken out. it also removes the only 'X' rtype
CAsat.drop(2036, inplace = True)

# %% [markdown]
# ### Investigate 'rtype' column.  Our presumption is that within the 'rtype' column 'S' is school data, and 'C' and 'D' rows are cumulative on a county and district levels.

# %%
# investigate 'r'-type. California MOE website states 'S' is school record, while D is district. does that
# mean that the rtype=D is the cumulative row for all the schools in the district?
print(CAsat['rtype'].value_counts(), '\n\n')
CAsat[CAsat['rtype'] == 'D']['dname'].value_counts()
# Out:
# S    1981
# D     539
# C      58
# Name: rtype, dtype: int64
# Washington Unified                       2
# Buckeye Union Elementary                 1
# Trinity Alps Unified                     1
# Piedmont City Unified                    1
# Redlands Unified                         1
#                                         ..
# Anderson Valley Unified                  1
# Sacramento County Office of Education    1
# Garden Grove Unified                     1
# Needles Unified                          1
# Twin Rivers Unified                      1
# Name: dname, Length: 538, dtype: int64

# %%
# it appears that rtype 'D' is a cumulative column: in rows with  rtype 'D' each district 
# name appears only once (except for the "Washinton United" which appears twice and will 
# be investigated later)

# %%
# a quick way to see if 'D' in rtype is total for 'S', and 'C' total for 'D' is to groupby rtype
CAsat.groupby('rtype')[['enroll12', 'numtsttakr12']].sum()
# Out:
#        enroll12  numtsttakr12
# rtype
# C        489650        170411
# D        489267        170404
# S        460926        170337

# %%
# based on the  cell above  - 'C' and 'D' behave like cumulative rows. The differences are
# negligible. The enrolment in 'S' is however 5% lower than 'D', which is substantial, 
# but likely due to homeschooling. (quick research shows that the number of home-schooled
# children in California is around 4%). The number of test-takers is virtually identical, as
# that number is not affected by the number of home-schooled students.

# to make sure it is not just the totals that add up but the individual constituents as well,
# groupby both district and rtype to see if the results match up for each district.

CAsat.groupby(['dname', 'rtype'])['numtsttakr12'].sum().head(10)
# Out:
# dname                               rtype
# ABC Unified                         D        631
#                                     S        631
# Acalanes Union High                 D        473
#                                     S        473
# Acton-Agua Dulce Unified            D        112
#                                     S        112
# Adelanto Elementary                 D          2
#                                     S          2
# Alameda County Office of Education  D         67
#                                     S         67
# Name: numtsttakr12, dtype: int64

# %%
# the numbers are the same, hence the rtype 'D' is definitely
# a cumulative row for 'S'. next check if the same holds for 'C' and 'D' 
CAsat.groupby(['cname', 'rtype'])['numtsttakr12'].sum().head(10)
# Out:
# cname    rtype
# Alameda  C        5946
#          D        5945
#          S        5918
# Alpine   C           0
# Amador   C          53
#          D          53
#          S          53
# Butte    C         551
#          D         551
#          S         551
# Name: numtsttakr12, dtype: int64

# %%
# the totals are the same, so the 'C' is the cumulative columns for all the 'D's

# %% [markdown]
# ### Investigate 'Washington United' district? Why are there two of them?

# %%
# back to Washington United district. Why are there two district with the same name?
CAsat[(CAsat['rtype'] == 'D') & (CAsat['dname'] == 'Washington Unified')]
# Out:
#       ccode rtype sname               dname   cname  enroll12  numtsttakr12  \
# 2095     57     D   NaN  Washington Unified    Yolo       563           182
# 2238     10     D   NaN  Washington Unified  Fresno       339            82
#
#       numerwbenchmark12  pcterwbenchmark12  nummathbenchmark12  \
# 2095              110.0              60.44                71.0
# 2238               36.0              43.90                 9.0
#
#       pctmathbenchmark12  totnumbothbenchmark12  pctbothbenchmark12
# 2095               39.01                   66.0               36.26
# 2238               10.98                    8.0                9.76

# %%
#it's ok. they are two separate districts in two different counties, so keep both in.

# %% [markdown]
# ### Drop unneccessary rows
# ### Reduce dataframe's size by removing all rows except the rtype 'C', since we will focus on  data on county level. Make a copy before making big changes.

# %%
# make a new df called CAsat3 where rtypes 'S' and 'D' are dropped, set county code as index, 
# sort by index and make index integer
CAsat3 = CAsat.copy()
CAsat3.drop(CAsat3.loc[CAsat3['rtype']=='S'].index, inplace=True)
CAsat3.drop(CAsat3.loc[CAsat3['rtype']=='D'].index, inplace=True)
CAsat3.set_index('ccode', inplace = True)
CAsat3.sort_index(inplace=True)
CAsat3.index = CAsat3.index.astype(int)

# %%
CAsat3.head(5)
# Out:
#       rtype sname dname      cname  enroll12  numtsttakr12  numerwbenchmark12  \
# ccode
# 1         C   NaN   NaN    Alameda     17567          5946             4566.0
# 2         C   NaN   NaN     Alpine         0             0                NaN
# 3         C   NaN   NaN     Amador       305            53               44.0
# 4         C   NaN   NaN      Butte      2551           551              453.0
# 5         C   NaN   NaN  Calaveras       451            90               81.0
#
#        pcterwbenchmark12  nummathbenchmark12  pctmathbenchmark12  \
# ccode
# 1                  76.79              3623.0               60.93
# 2                    NaN                 NaN                 NaN
# 3                  83.02                35.0               66.04
# 4                  82.21               349.0               63.34
# 5                  90.00                60.0               66.67
#
#        totnumbothbenchmark12  pctbothbenchmark12
# ccode
# ...

# %% [markdown]
# ### After dropping many rows, some columns became redundant. Drop & rename

# %%
# remove columns with no info
CAsat3.drop(['rtype', 'sname', 'dname'], axis=1, inplace=True)

# %%
#make columns names shorter
CAsat3.columns = CAsat3.columns.str.replace('benchmark12', '')
CAsat3.columns = CAsat3.columns.str.replace('12', '')

# %%
CAsat3.head()
# Out:
#            cname  enroll  numtsttakr  numerw  pcterw  nummath  pctmath  \
# ccode
# 1        Alameda   17567        5946  4566.0   76.79   3623.0    60.93
# 2         Alpine       0           0     NaN     NaN      NaN      NaN
# 3         Amador     305          53    44.0   83.02     35.0    66.04
# 4          Butte    2551         551   453.0   82.21    349.0    63.34
# 5      Calaveras     451          90    81.0   90.00     60.0    66.67
#
#        totnumboth  pctboth
# ccode
# 1          3458.0    58.16
# 2             NaN      NaN
# 3            33.0    62.26
# 4           332.0    60.25
# 5            60.0    66.67

# %%
# some counties are very small and can easily have misleading stats.
# we'll decide which ones to remove later

# %% [markdown]
# <a id = '2.2'><a/>
# # 2.2 CAL2019 ACT cleanup
# * [Back To Top](#Content)

# %% [markdown]
# ### This cleanup is very similar to the cleanup done on the CAL2019 SAT table. Same (or similar) steps will be followed, with less commenting due to repetition

# %%
CAact.columns = CAact.columns.str.lower()
CAact.head()
# Out:
#             cds  ccode     cdcode      scode rtype  \
# 0  3.366993e+13   33.0  3366993.0   129882.0     S
# 1  1.964212e+13   19.0  1964212.0  1995596.0     S
# 2  1.563776e+13   15.0  1563776.0  1530377.0     S
# 3  4.369666e+13   43.0  4369666.0  4333795.0     S
# 4  1.964733e+13   19.0  1964733.0  1935121.0     S
#
#                              sname                  dname        cname  \
# 0  21st Century Learning Institute       Beaumont Unified    Riverside
# 1      ABC Secondary (Alternative)            ABC Unified  Los Angeles
# 2      Abraham Lincoln Alternative  Southern Kern Unified         Kern
# 3             Abraham Lincoln High       San Jose Unified  Santa Clara
# 4      Abraham Lincoln Senior High    Los Angeles Unified  Los Angeles
#
#    enroll12  numtsttakr avgscrread avgscreng avgscrmath avgscrsci numge21  \
# 0      18.0         0.0        NaN       NaN        NaN       NaN     NaN
# 1      58.0         0.0        NaN       NaN        NaN       NaN     NaN
# ...

# %%
# drop columns
drops = ['unnamed: 17', 'year', 'cds', 'cdcode', 'scode',]

CAact.drop(drops, axis=1, inplace=True)

# %%
CAact.head()
# Out:
#    ccode rtype                            sname                  dname  \
# 0   33.0     S  21st Century Learning Institute       Beaumont Unified
# 1   19.0     S      ABC Secondary (Alternative)            ABC Unified
# 2   15.0     S      Abraham Lincoln Alternative  Southern Kern Unified
# 3   43.0     S             Abraham Lincoln High       San Jose Unified
# 4   19.0     S      Abraham Lincoln Senior High    Los Angeles Unified
#
#          cname  enroll12  numtsttakr avgscrread avgscreng avgscrmath  \
# 0    Riverside      18.0         0.0        NaN       NaN        NaN
# 1  Los Angeles      58.0         0.0        NaN       NaN        NaN
# 2         Kern      18.0         0.0        NaN       NaN        NaN
# 3  Santa Clara     463.0        53.0         23        22         22
# 4  Los Angeles     226.0        19.0         21        20         23
#
#   avgscrsci numge21 pctge21
# 0       NaN     NaN     NaN
# 1       NaN     NaN     NaN
# 2       NaN     NaN     NaN
# ...

# %%
# this time no checking if 'C' and 'D' columns are cumulative. we know they are from before
CAact[CAact['cname'] == 'State of California']

#'State of California' is a cumalative row, so it needs to be taken out.
CAact.drop(2070, inplace = True)

# %%
CAact.info()
#why are columns 7-12 objects?
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2309 entries, 0 to 2309
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ccode       2308 non-null   float64
#  1   rtype       2308 non-null   object
#  2   sname       1728 non-null   object
#  3   dname       2250 non-null   object
#  4   cname       2308 non-null   object
#  5   enroll12    2308 non-null   float64
#  6   numtsttakr  2308 non-null   float64
#  7   avgscrread  1952 non-null   object
#  8   avgscreng   1952 non-null   object
#  9   avgscrmath  1952 non-null   object
#  10  avgscrsci   1952 non-null   object
#  11  numge21     1952 non-null   object
#  12  pctge21     1952 non-null   object
# dtypes: float64(3), object(10)
# memory usage: 252.5+ KB

# %%
CAact['numge21'].value_counts()
# Out:
# *      532
# 10      45
# 7       39
# 8       34
# 13      34
#       ...
# 203      1
# 105      1
# 133      1
# 544      1
# 431      1
# Name: numge21, Length: 278, dtype: int64

# %%
# dataframe seems to have many '*'. replace them with Nan 
CAact.replace('*',np.nan, inplace= True)

# now convert cleaned columns to float
for col in CAact.columns:
        CAact[col] = CAact[col].astype(float, errors = 'ignore')
        
print(CAact.info())
CAact.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2309 entries, 0 to 2309
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ccode       2308 non-null   float64
#  1   rtype       2308 non-null   object
#  2   sname       1728 non-null   object
#  3   dname       2250 non-null   object
#  4   cname       2308 non-null   object
#  5   enroll12    2308 non-null   float64
#  6   numtsttakr  2308 non-null   float64
#  7   avgscrread  1420 non-null   float64
#  8   avgscreng   1420 non-null   float64
#  9   avgscrmath  1420 non-null   float64
#  10  avgscrsci   1420 non-null   float64
#  11  numge21     1420 non-null   float64
#  12  pctge21     1420 non-null   float64
# dtypes: float64(9), object(4)
# memory usage: 252.5+ KB
# None
#    ccode rtype                            sname                  dname  \
# 0   33.0     S  21st Century Learning Institute       Beaumont Unified
# ...

# %%
# create a new column with ACT total score (ie the average of the four ACT subjects)
CAact['avgscrtot'] = CAact[['avgscrread','avgscreng','avgscrmath','avgscrsci']].mean(axis=1)

# %%
CAact.head()
# Out:
#    ccode rtype                            sname                  dname  \
# 0   33.0     S  21st Century Learning Institute       Beaumont Unified
# 1   19.0     S      ABC Secondary (Alternative)            ABC Unified
# 2   15.0     S      Abraham Lincoln Alternative  Southern Kern Unified
# 3   43.0     S             Abraham Lincoln High       San Jose Unified
# 4   19.0     S      Abraham Lincoln Senior High    Los Angeles Unified
#
#          cname  enroll12  numtsttakr  avgscrread  avgscreng  avgscrmath  \
# 0    Riverside      18.0         0.0         NaN        NaN         NaN
# 1  Los Angeles      58.0         0.0         NaN        NaN         NaN
# 2         Kern      18.0         0.0         NaN        NaN         NaN
# 3  Santa Clara     463.0        53.0        23.0       22.0        22.0
# 4  Los Angeles     226.0        19.0        21.0       20.0        23.0
#
#    avgscrsci  numge21  pctge21  avgscrtot
# 0        NaN      NaN      NaN        NaN
# ...

# %%
# make a new df called CAact3 where rtypes 'S' and 'D' are dropped, set county code as index, 
# sort by index and make index integer
CAact3 = CAact.copy()
CAact3.drop(CAact3.loc[CAact3['rtype']=='S'].index, inplace=True)
CAact3.drop(CAact3.loc[CAact3['rtype']=='D'].index, inplace=True)
CAact3.set_index('ccode', inplace = True)
CAact3.sort_index(inplace=True)
CAact3.drop(np.nan, inplace=True)
CAact3.index = CAact3.index.astype(int)

# %%
CAact3.tail()
# Out:
#       rtype sname dname     cname  enroll12  numtsttakr  avgscrread  \
# ccode
# 54        C   NaN   NaN    Tulare    7558.0       951.0        20.0
# 55        C   NaN   NaN  Tuolumne     518.0        23.0        26.0
# 56        C   NaN   NaN   Ventura   10750.0      1552.0        25.0
# 57        C   NaN   NaN      Yolo    2299.0       355.0        23.0
# 58        C   NaN   NaN      Yuba     977.0        64.0        21.0
#
#        avgscreng  avgscrmath  avgscrsci  numge21  pctge21  avgscrtot
# ccode
# 54          18.0        19.0       19.0    326.0    34.28      19.00
# 55          23.0        23.0       23.0     18.0    78.26      23.75
# 56          24.0        24.0       24.0   1086.0    69.97      24.25
# 57          23.0        23.0       23.0    223.0    62.82      23.00
# 58          19.0        20.0       20.0     30.0    46.88      20.00

# %%
# remove columns with no info and remove cname, enroll12 as they'll become duplicates when merged
CAact3.drop(['rtype', 'sname', 'dname', 'cname','enroll12'], axis=1, inplace=True)

# %%
CAact3.shape
# Out:
# (58, 8)

# %% [markdown]
# ### Merge California SAT and ACT dataframes on county column

# %%
CA2019=pd.merge(CAsat3,CAact3, on='ccode')

# %%
# some counties have very few students. we'll look into that later
CA2019.head()
# Out:
#            cname  enroll  numtsttakr_x  numerw  pcterw  nummath  pctmath  \
# ccode
# 1        Alameda   17567          5946  4566.0   76.79   3623.0    60.93
# 2         Alpine       0             0     NaN     NaN      NaN      NaN
# 3         Amador     305            53    44.0   83.02     35.0    66.04
# 4          Butte    2551           551   453.0   82.21    349.0    63.34
# 5      Calaveras     451            90    81.0   90.00     60.0    66.67
#
#        totnumboth  pctboth  numtsttakr_y  avgscrread  avgscreng  avgscrmath  \
# ccode
# 1          3458.0    58.16        3630.0        25.0       24.0        24.0
# 2             NaN      NaN           0.0         NaN        NaN         NaN
# 3            33.0    62.26          37.0        24.0       23.0        23.0
# 4           332.0    60.25         226.0        23.0       22.0        23.0
# 5            60.0    66.67          31.0        26.0       24.0        24.0
#
#        avgscrsci  numge21  pctge21  avgscrtot
# ccode
# ...

# %% [markdown]
# <a id = '2.3'><a/>
# # 2.3 CAL Income Table Cleanup
# * [Back To Top](#Content)

# %% [markdown]
# ### Cleaning up dataframe CAincome which has only two columns - county name and averge household income for the county

# %%
CAincome.head()
# Out:
#       County   Value
# 0    Alameda  92,574
# 1     Alpine  64,688
# 2     Amador  61,198
# 3      Butte  48,443
# 4  Calaveras  58,151

# %% [markdown]
# ### Make indices the same for this and CA2019 for ease of merginf.
# ### Drop columns so they don't become duplicates
# ### Rename columns for clarity

# %%
# make indeces the same CA2019 dataframe and use 'join' to merge on them
CAincome.index+=1
CA2019 = CA2019.join(CAincome)
CA2019.drop('County', axis =1, inplace=True)
CA2019.rename(columns={'Value':'hhincome','numtsttakr_x':'numtsttakrsat',
                      'numtsttakr_y':'numtsttakract'}, inplace= True)

# %% [markdown]
# > <font size = 3 color = "crimson"> Some tips when renaming columns, especially for larger datasets. <br> 1. Keep column names short. <br> 2. Try to use .lower() instead of manually changing column names to lowercase <br> list comprehension df.columns = ['sat17_' + col.lower() for col in df.columns]<br> 3. Try to use df.add_prefix() or df.add_suffix() to add to column names<br>
# <br>If you write a function to rename columns, it can be used for other dataframes too.
#     <br><br>def update_cols(df,prefix):<br>
#     df.columns = [x.lower().replace('evidence-based reading and writing','ebrw').replace('participation','rate')
#                   for x in df.columns] <br>
#     df.columns = [prefix + x if x !='state' else x for x in df.columns] <br>
#     return df</font>

# %%
# some counties have small number of test takers and might skew the stats.
# upon inspecting the data, decision is to remove those with enrollment under 600
CA2019.drop(CA2019.loc[CA2019['enroll'] < 601].index, inplace=True)

# %% [markdown]
# ### get rid of unnecessary characters and turn hhincome column into float

# %%
#remove ',' from household income and turn the column into type float
CA2019['hhincome'] = CA2019['hhincome'].map(lambda v: v.replace(",", ''))
CA2019['hhincome'] = CA2019['hhincome'].astype(int)

# %%
CA2019.head()
# Out:
#               cname  enroll  numtsttakrsat  numerw  pcterw  nummath  pctmath  \
# ccode
# 1           Alameda   17567           5946  4566.0   76.79   3623.0    60.93
# 4             Butte    2551            551   453.0   82.21    349.0    63.34
# 7      Contra Costa   14593           5412  3798.0   70.18   2814.0    52.00
# 9         El Dorado    2226            604   547.0   90.56    458.0    75.83
# 10           Fresno   14299           4070  2664.0   65.45   1619.0    39.78
#
#        totnumboth  pctboth  numtsttakract  avgscrread  avgscreng  avgscrmath  \
# ccode
# 1          3458.0    58.16         3630.0        25.0       24.0        24.0
# 4           332.0    60.25          226.0        23.0       22.0        23.0
# 7          2721.0    50.28         3183.0        25.0       25.0        24.0
# 9           442.0    73.18          465.0        25.0       24.0        25.0
# 10         1538.0    37.79         1805.0        21.0       20.0        20.0
#
# ...

# %% [markdown]
# <a id = '2.4'><a/>
# # 2.4 USA 2019 ACT and SAT cleanup
# * [Back To Top](#Content)

# %% [markdown]
# ### Cleaning up 2019 ACT and SAT National data

# %%
SAT19.head()
# Out:
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065

# %%
ACT19.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       18.9
# 1      Alaska           38%       20.1
# 2     Arizona           73%       19.0
# 3    Arkansas          100%       19.3
# 4  California           23%       22.6

# %%
SAT19.isnull().sum()
# Out:
# State                 0
# Participation Rate    0
# EBRW                  0
# Math                  0
# Total                 0
# dtype: int64

# %%
# make all columns all lowercase
ACT19.columns = ACT19.columns.str.lower()
SAT19.columns = SAT19.columns.str.lower()

# %%
#simplify column names
SAT19.rename(columns={'participation rate':'participation'}, inplace=True)

# %%
# make use of the definition from the Coding Challenge
ACT19['participation'] = ACT19['participation'].apply(lambda v: convert_percent(v))
SAT19['participation'] = SAT19['participation'].apply(lambda v: convert_percent(v))

# %%
print(ACT19.shape, SAT19.shape)
# Out:
# (52, 3) (53, 5)

# %%
# numbers of rows is different. make the number of rows, as well as the list of states in both
# tables the same. display all rows to do that

# %%
display(ACT19)
display(SAT19)
# Out:
#                    state  participation  composite
# 0                Alabama           1.00       18.9
# 1                 Alaska           0.38       20.1
# 2                Arizona           0.73       19.0
# 3               Arkansas           1.00       19.3
# 4             California           0.23       22.6
# 5               Colorado           0.27       23.8
# 6            Connecticut           0.22       25.5
# 7               Delaware           0.13       24.1
# 8   District of Columbia           0.32       23.5
# 9                Florida           0.54       20.1
# 10               Georgia           0.49       21.4
# 11                Hawaii           0.80       19.0
# 12                 Idaho           0.31       22.5
# 13              Illinois           0.35       24.3
# 14               Indiana           0.29       22.5
# 15                  Iowa           0.66       21.6
# 16                Kansas           0.72       21.2
# ...

# %%
# remove National (cumulative column) from ACT, and Virgin Islands and Puerto Rico from SAT
# (keep 50 states + District of Columbia only), as the incomes there are difficult to compare to
# US mainland due to the cost of living adjustments and to make ACT and SAT data contain the 
# same states

ACT19.drop(51, inplace = True)
SAT19.drop([39, 47], inplace = True)

# %%
#align the indeces of the two dataframes
SAT19.reset_index(drop = True, inplace=True)

# %% [markdown]
# ### Merge dataframes, add suffices since many column names are the same

# %%
#this time use 'merge' rather than 'join' to get the useful suffixes.
USA2019 = SAT19.merge(ACT19, left_index=True, right_index=True, suffixes=('_sat', '_act'))

# %%
#drop duplicate columns and clean up column names
USA2019.drop('state_act', axis=1, inplace=True)
USA2019.rename(columns={'state_sat':'state', 'ebrw':'english_sat',
                        'math':'math_sat', 'total':'total_sat',
                       'composite':'total_act'}, inplace=True)

# %%
USA2019.head(3)
# Out:
#      state  participation_sat  english_sat  math_sat  total_sat  \
# 0  Alabama               0.07          583       560       1143
# 1   Alaska               0.41          556       541       1097
# 2  Arizona               0.31          569       565       1134
#
#    participation_act  total_act
# 0               1.00       18.9
# 1               0.38       20.1
# 2               0.73       19.0

# %% [markdown]
# <a id = '2.5'><a/>
# # 2.5 USA income table cleanup
# * [Back To Top](#Content)

# %% [markdown]
# ### The final cleanup, the national data with average income by state

# %%
USincome
# Out:
#    Geographic Area Name  Estimate!!Households!!Median income (dollars)
# 0               Alabama                                          49861
# 1                Alaska                                          74346
# 2               Arizona                                          59246
# 3              Arkansas                                          47062
# 4            California                                          75277
# 5              Colorado                                          71953
# 6           Connecticut                                          76348
# 7              Delaware                                          64805
# 8               Florida                                          55462
# 9               Georgia                                          58756
# 10               Hawaii                                          80212
# 11                Idaho                                          55583
# ...

# %%
#replace Puerto Rico's with District of Columbia's income data (source: St Louis Fed)
USincome.loc[50] = ['District of Columbia', 88393]

# %%
#rename columns
USincome.rename(columns={'Geographic Area Name':'state',
                         'Estimate!!Households!!Median income (dollars)':'median_income'},
                inplace=True)

# %%
#get USincome index to align with USA2019 for the ease of merging
USincome = USincome.sort_values(by = 'state').reset_index(drop=True)

# %%
USincome.head()
# Out:
#         state  median_income
# 0     Alabama          49861
# 1      Alaska          74346
# 2     Arizona          59246
# 3    Arkansas          47062
# 4  California          75277

# %%
# drop state before mergine so it doesn't become a duplicat
USincome.drop('state',axis=1, inplace=True)

# %% [markdown]
# ### Merge national income data with national SAT and ACT scores data

# %%
USA2019 = USA2019.merge(USincome, left_index=True, right_index=True)

# %%
USA2019.head()
# Out:
#         state  participation_sat  english_sat  math_sat  total_sat  \
# 0     Alabama               0.07          583       560       1143
# 1      Alaska               0.41          556       541       1097
# 2     Arizona               0.31          569       565       1134
# 3    Arkansas               0.06          582       559       1141
# 4  California               0.63          534       531       1065
#
#    participation_act  total_act  median_income
# 0               1.00       18.9          49861
# 1               0.38       20.1          74346
# 2               0.73       19.0          59246
# 3               1.00       19.3          47062
# 4               0.23       22.6          75277

# %%
CA2019.head()
# Out:
#               cname  enroll  numtsttakrsat  numerw  pcterw  nummath  pctmath  \
# ccode
# 1           Alameda   17567           5946  4566.0   76.79   3623.0    60.93
# 4             Butte    2551            551   453.0   82.21    349.0    63.34
# 7      Contra Costa   14593           5412  3798.0   70.18   2814.0    52.00
# 9         El Dorado    2226            604   547.0   90.56    458.0    75.83
# 10           Fresno   14299           4070  2664.0   65.45   1619.0    39.78
#
#        totnumboth  pctboth  numtsttakract  avgscrread  avgscreng  avgscrmath  \
# ccode
# 1          3458.0    58.16         3630.0        25.0       24.0        24.0
# 4           332.0    60.25          226.0        23.0       22.0        23.0
# 7          2721.0    50.28         3183.0        25.0       25.0        24.0
# 9           442.0    73.18          465.0        25.0       24.0        25.0
# 10         1538.0    37.79         1805.0        21.0       20.0        20.0
#
# ...

# %% [markdown]
# <a id = '2.6'><a/>
# # 2.6 Quantile cuts and final cleanup
# * [Back To Top](#Content)

# %% [markdown]
# ### After all the merging, 2 main dataframes are left: one for California incomes and test scores (CA2019) and the other for the national incomes and scores (USA2019)

# %%
# big changes to the dataframe, so make a copy first, add 'q' to the name to signify 
# quantile cut
CA2019q = CA2019.copy()

# %% [markdown]
# ### Create a new categorical column - split the household income equally into 'high', 'middle' and 'low"

# %%
#create a new categorical column based on county's income rank
CA2019q['income_q'] = pd.qcut(CA2019['hhincome'], q=3, labels = ['low', 'middle', 'high'])

# %%
CA2019q.head()
# Out:
#               cname  enroll  numtsttakrsat  numerw  pcterw  nummath  pctmath  \
# ccode
# 1           Alameda   17567           5946  4566.0   76.79   3623.0    60.93
# 4             Butte    2551            551   453.0   82.21    349.0    63.34
# 7      Contra Costa   14593           5412  3798.0   70.18   2814.0    52.00
# 9         El Dorado    2226            604   547.0   90.56    458.0    75.83
# 10           Fresno   14299           4070  2664.0   65.45   1619.0    39.78
#
#        totnumboth  pctboth  numtsttakract  avgscrread  avgscreng  avgscrmath  \
# ccode
# 1          3458.0    58.16         3630.0        25.0       24.0        24.0
# 4           332.0    60.25          226.0        23.0       22.0        23.0
# 7          2721.0    50.28         3183.0        25.0       25.0        24.0
# 9           442.0    73.18          465.0        25.0       24.0        25.0
# 10         1538.0    37.79         1805.0        21.0       20.0        20.0
#
# ...

# %% [markdown]
# ### Similarly, create a categorical income column in the  USA

# %%
USA2019q = USA2019.copy()

# %%
USA2019q['med_income_q'] = pd.qcut(USA2019q['median_income'], q=3, labels = ['low', 'middle', 'high'])

# %% [markdown]
# ## And one final cleanup before saving the dataframes to the disk and commencing data exploration:

# %% [markdown]
# ### - upon closer insepction, a few more columns of CA2019q can be dropped as they will not aid in analysis. also, change the column names to make them more descriptive

# %%
CA2019q.head(1)
# Out:
#          cname  enroll  numtsttakrsat  numerw  pcterw  nummath  pctmath  \
# ccode
# 1      Alameda   17567           5946  4566.0   76.79   3623.0    60.93
#
#        totnumboth  pctboth  numtsttakract  avgscrread  avgscreng  avgscrmath  \
# ccode
# 1          3458.0    58.16         3630.0        25.0       24.0        24.0
#
#        avgscrsci  numge21  pctge21  avgscrtot  hhincome income_q
# ccode
# 1           24.0   2459.0    67.74      24.25     92574     high

# %% [markdown]
# ### Drop columns

# %%
# numerical columns do not give us any information. keep only the perctange ones
CA2019q.drop(columns=['numerw', 'nummath', 'totnumboth', 'numge21'], inplace=True)

# %% [markdown]
# ### Rename columns

# %%
CA2019q.rename({'cname':'county_name', 'numtsttakrsat':'testtkr_sat',
              'pcterw':'eng_bmark_sat','pctmath':'math_bmark_sat',
              'pctboth':'ttl_bmark_sat', 'numtsttakract':'testtkr_act',
              'avgscrread':'read_act','avgscreng':'eng_act',
              'avgscrmath': 'math_act', 'avgscrsci': 'sci_act',
              'pctge21': 'ttl_bmark_act', 'avgscrtot': 'ttl_act',
              'hhincome':'hh_income', 'income_q':'income_third'}, axis=1, inplace=True)

# %% [markdown]
# ### Save both dataframes to hard drive as .csv files

# %%
CA2019.to_csv('Harry_CA2019.csv')
USA2019.to_csv('Harry_USA2019.csv')

# %% [markdown]
# > <font size = 3 color = "crimson"> Good to set the argument index = False to prevent a column of row index being created in the csv</font>

# %% [markdown]
# <a id = '2.7'><a/>
# # 2.7 Data Dictionary
# * [Back To Top](#Content)

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# **Data Dictionary:** *Description, type and source of all the features used in this analysis.*
# #                         CA2019q DataFrame
# |Feature|Type|Dataset|Description|
# |---------|---|---|---|
# |county_name|object|SAT2019CA|county name|
# |enroll|float|SAT2019CA|SAT student enrollment|
# |testtkr_sat|float|SAT2019CA|SAT test-taker number|
# |eng_bmark_sat|float|SAT2019CA|SAT engl meeting benchmark (%)|
# |math_bmark_sat|float|SAT2019CA|SAT math meeting benchmark (%)|
# |ttl_bmark_sat|float|SAT2019CA|SAT total meeting benchmark (%)|
# |testtkr_act|float|ACT2019CA|ACT test-taker number|
# |read_act|float|ACT2019CA|ACT reading score|
# |eng_act|float|ACT2019CA|ACT english score|
# |math_act|float|ACT2019CA|ACT  score|math
# |sci_act|float|ACT2019CA|ACT science score|
# |ttl_bmark_act|float|ACT2019CA|ACT total meeting benchmark (%)|
# |ttl_act|float|ACT2019CA|ACT total score|
# |hh_income|float|US Census|median household income (county)|
# |income_third|Cat|US Census|hhold income rank (high,middle,low)|
#
# #                       USA2019q DataFrame
# |Feature|Type|Dataset|Description|
# |---------|---|---|---|
# |state|object|2019_SAT|state name|
# |participation_sat|float|2019_SAT|SAT participation rate|
# |english_sat|float|2019_SAT|avg english SAT score|
# |math_sat|float|2019_SAT|avg math SAT score|
# |total_sat|float|2019_SAT|avg total SAT score|
# |participation_act|float|2019_SAT|ACT participation rate|
# |total_act|float|2019_SAT|avg total ACT score|
# |median_income|float|Am Community Survey|2018 median HH income|
# |med_income_q|Cat|Am Community Survey|2018 median income rank|

# %% [markdown]
# > <font size = 3 color = "crimson"> Do also include the theoretical max and min range in description whenever applicable.</font>

# %% [markdown]
# <a id = '3.0'><a/>
# ## 3.0 Exploratory Data Analysis
# * [Back To Top](#Content)
#
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# ### Summary statistics

# %%
CA2019q.describe()
# Out:
#               enroll   testtkr_sat  eng_bmark_sat  math_bmark_sat  \
# count      42.000000     42.000000      42.000000       42.000000
# mean    11544.738095   4036.976190      74.076190       52.322857
# std     19556.528902   8074.107449       8.896743       12.041705
# min       667.000000     91.000000      59.460000       30.770000
# 25%      2177.250000    470.000000      66.800000       41.325000
# 50%      4702.000000   1268.500000      75.305000       52.325000
# 75%     13616.250000   4000.750000      80.880000       61.160000
# max    114618.000000  48676.000000      90.560000       75.830000
#
#        ttl_bmark_sat   testtkr_act   read_act    eng_act   math_act  \
# count      42.000000     42.000000  42.000000  42.000000  42.000000
# mean       49.781429   1957.285714  22.619048  21.619048  21.880952
# std        12.159251   3587.300101   2.378280   2.556220   2.132242
# min        28.730000     64.000000  18.000000  17.000000  18.000000
# ...

# %% [markdown]
# > <font size = 3 color = "crimson"> Consider transposing the output if it cannot be displayed due to too many columns<br><br>CA2019q.describe().T</font>

# %%
USA2019q.describe()
# Out:
#        participation_sat  english_sat    math_sat    total_sat  \
# count          51.000000    51.000000   51.000000    51.000000
# mean            0.490588   560.803922  552.196078  1113.078431
# std             0.387476    46.248035   51.290553    97.197910
# min             0.020000   483.000000  460.000000   943.000000
# 25%             0.055000   527.500000  511.500000  1038.000000
# 50%             0.540000   550.000000  546.000000  1097.000000
# 75%             0.820000   612.000000  599.000000  1210.000000
# max             1.000000   636.000000  648.000000  1284.000000
#
#        participation_act  total_act  median_income
# count          51.000000  51.000000      51.000000
# mean            0.586667  21.464706   62075.627451
# std             0.345159   2.194523   10759.600927
# min             0.060000  17.900000   44097.000000
# 25%             0.245000  19.800000   55395.000000
# 50%             0.540000  21.100000   59955.000000
# ...

# %%
# no values are outside reasonable ranges

# %% [markdown]
# > <font size = 3 color = "crimson"> The comment above needs to be clearer. Providing the theoretical max and min scores would help.</font>

# %% [markdown]
# ### use dictionary comprehension to create features paired up with their st dev

# %%
from pandas.api.types import is_numeric_dtype
dict_CA = {colname: round(stdev((col))) for colname, col in CA2019q.items()
       if is_numeric_dtype(col)}
dict_CA
# Out:
# {'enroll': 19322,
#  'testtkr_sat': 7977,
#  'eng_bmark_sat': 9,
#  'math_bmark_sat': 12,
#  'ttl_bmark_sat': 12,
#  'testtkr_act': 3544,
#  'read_act': 2,
#  'eng_act': 3,
#  'math_act': 2,
#  'sci_act': 2,
#  'ttl_bmark_act': 16,
#  'ttl_act': 2,
#  'hh_income': 19650}

# %%
dict_USA = {colname: round(stdev((col)),2) for colname, col in USA2019q.items()
       if is_numeric_dtype(col)}
dict_USA
# Out:
# {'participation_sat': 0.38,
#  'english_sat': 45.79,
#  'math_sat': 50.79,
#  'total_sat': 96.24,
#  'participation_act': 0.34,
#  'total_act': 2.17,
#  'median_income': 10653.59}

# %% [markdown]
# ###  Check if SAT scores display less economic bias than ACT

# %%
# Check if nationally the scores are dependent on state income
round(USA2019q.groupby('med_income_q')[['total_sat','total_act']].mean(), 2)
# Out:
#               total_sat  total_act
# med_income_q
# low             1106.00      20.08
# middle          1150.71      21.24
# high            1082.53      23.07

# %% [markdown]
# > <font size = 3 color = "crimson"> Be mindful about your choice of words here. The word dependent would imply causation instead of correlation. </font>

# %% [markdown]
# ### Masking and sorting

# %%
#  Nationally, ACT test scores a rise with income, but not SAT. Let's see why that is.
# list states sorted by income, high to low
USA2019q.sort_values('median_income', ascending = False).head(15)
# Out:
#                    state  participation_sat  english_sat  math_sat  total_sat  \
# 8   District of Columbia               0.94          495       480        975
# 20              Maryland               0.82          535       523       1058
# 30            New Jersey               0.82          544       545       1090
# 11                Hawaii               0.54          550       550       1100
# 21         Massachusetts               0.81          559       561       1120
# 6            Connecticut               1.00          529       516       1046
# 4             California               0.63          534       531       1065
# 29         New Hampshire               0.95          533       526       1059
# 1                 Alaska               0.41          556       541       1097
# 47            Washington               0.70          539       535       1074
# 46              Virginia               0.68          567       551       1119
# ...

# %%
# participation rates seem high for high-income states.
# as higher participation rates lead to lower scores (to be shown later),
# that might explain the lower scores among high-income states

USA2019q.groupby('med_income_q')[['participation_sat', 'participation_act']].mean()
# Out:
#               participation_sat  participation_act
# med_income_q
# low                    0.392941           0.760000
# middle                 0.362941           0.635294
# high                   0.715882           0.364706

# %%
# high income states have low ACT participation and high SAT participation. That is largely a
# product of state requirements and not a sign of economic bias

# next check the correlation between the sores and the participation rates
corr_sat = USA2019q["participation_sat"].corr(USA2019q["total_sat"])
corr_act = USA2019q["participation_act"].corr(USA2019q["total_act"])
print(f'The correlation between the SAT participation rate and scores is {corr_sat:.2f}')
print(f'The correlation between the ACT participation rate and scores is {corr_act:.2f}')
# Out:
# The correlation between the SAT participation rate and scores is -0.86
# The correlation between the ACT participation rate and scores is -0.87

# %% [markdown]
# ### We established that there is a major difference in SAT and ACT test-takers. High income states have high SAT participation rates yet low ACT participation rates.
# ### High participation rates have a strong negative correlation with  scores, and that explains away the apparent lack of economic bias of SAT scores.
# ### In other words, low SAT scores of high-income states are due to the high participation rates among those states.

# %%
# to approach the problem from a different angle, list top 15 states by participation rate
tempdf = USA2019q.sort_values('participation_sat', ascending=False).head(15)

# %%
# def highlight_max(x):
#     return ['background-color: yellow' if v == x.max() else ''
#                 for v in x]

# df = pd.DataFrame(np.random.randn(5, 2))
# df.style.apply(highlight_max)

# %%
def highlight(s, value, column):
    """ the function takes a df, a value and a column and highlights 
    rows in the df where the column cell equals the value
    """
    is_max = pd.Series(data=False, index=s.index)
    is_max[column] = (s.loc[column] == value)
    print(is_max)
    return ['background-color: lightsalmon' if is_max.any() else '' for v in is_max]

# %% [markdown]
# > <font size = 3 color = "crimson"> Well done for writing a custom function!! </font>

# %%
tempdf.style.apply(highlight, value='high', column=['med_income_q'], axis=1)
# Out:
# state                False
# participation_sat    False
# english_sat          False
# math_sat             False
# total_sat            False
# participation_act    False
# total_act            False
# median_income        False
# med_income_q         False
# dtype: bool
# state                False
# participation_sat    False
# english_sat          False
# math_sat             False
# total_sat            False
# participation_act    False
# total_act            False
# median_income        False
# med_income_q          True
# dtype: bool
# state                False
# participation_sat    False
# english_sat          False
# math_sat             False
# total_sat            False
# participation_act    False
# total_act            False
# median_income        False
# med_income_q         False
# dtype: bool
# state                False
# participation_sat    False
# english_sat          False
# math_sat             False
# total_sat            False
# participation_act    False
# ...

# %%
# in the table above listing top 15 states by participation, the highlighted 9 are
# high-income states. As only 1/3 states overall are "high" income, they are overrepresented
# in the table

#delete the temporary df
del tempdf

# %% [markdown]
# ### Use data from one state (California) to see if there is difference in SAT and ACT in terms of economic bias. Narrowing down to one state allows us to control for the wide disparity that exists among the 50 states in terms of participation rates, which are a political product of state requirements, as some states opt for mandotory ACT, SAT or both.

# %%
# check if California SAT and ACT scores are dependent on the local county income
CA2019q.groupby('income_third')[['ttl_bmark_sat','ttl_bmark_act', 'ttl_act']].mean().round(2)
# Out:
#               ttl_bmark_sat  ttl_bmark_act  ttl_act
# income_third
# low                   43.78          46.14    20.50
# middle                48.83          54.95    21.71
# high                  56.73          67.25    23.70

# %%
# the table above is as expected - the scores rise with incomes and this was the final proof
# we needed to show that SAT is not more economically biased than ACT

# %%
print(CA2019q.groupby('income_third')[['eng_bmark_sat', 'math_bmark_sat']].mean())
# Out:
#               eng_bmark_sat  math_bmark_sat
# income_third
# low               71.975000       46.420000
# middle            73.380000       51.110714
# high              76.873571       59.437857

# %%
#The cell above shows that the biggest difference between the high and the low income counties
# is in their math scores - almost 30% difference (46 vs 59), vs just 8% difference in 
# english (71 vs 76)

diff_avg = CA2019q[['math_act', "eng_act"]].diff(axis=1).mean()[1]
diff_min = CA2019q[['math_act', "eng_act"]].diff(axis=1).min()[1]
diff_max = CA2019q[['math_act', "eng_act"]].diff(axis=1).max()[1]
print("                    2019 CALIFORNIA ACT             \n")
print('*'*74,'\n')
print(f'The average difference between a county\'s math and english  is {abs(diff_avg):.2f} points')
print(f'The most any California\'s county math score exceeds english is {abs(diff_min):.2f} points')
print(f'The most any California\'s county english score exceeds math is {abs(diff_max):.2f} points')
# Out:
#                     2019 CALIFORNIA ACT
#
# **************************************************************************
#
# The average difference between a county's math and english  is 0.26 points
# The most any California's county math score exceeds english is 2.00 points
# The most any California's county english score exceeds math is 1.00 points

# %%
# it is important for the low-income areas to catch up in math. Find the California county with
# substantially higher math scores than english scores (the max difference is 2pts,
# so we'll search > 1.5Pts)

CA2019q[((CA2019q['math_act'] - CA2019q['eng_act']) > 1.5)]
# Out:
#           county_name  enroll  testtkr_sat  eng_bmark_sat  math_bmark_sat  \
# ccode
# 36     San Bernardino   31635        10544          66.52           41.43
#
#        ttl_bmark_sat  testtkr_act  read_act  eng_act  math_act  sci_act  \
# ccode
# 36             38.72       5418.0      18.0     17.0      19.0     18.0
#
#        ttl_bmark_act  ttl_act  hh_income income_third
# ccode
# 36             28.61     18.0      60164       middle

# %%
diff_avg = USA2019q[['math_sat', "english_sat"]].diff(axis=1).mean()[1]
diff_min = abs(USA2019q[['math_sat', "english_sat"]].diff(axis=1).min()[1])
diff_max = USA2019q[['math_sat', "english_sat"]].diff(axis=1).max()[1]

print(f'The average state has an SAT english score that is {diff_avg:.2f}pts higher than the average math score')
print(f'The lowest of any state\'s SAT english score is {diff_min:.2f}pts lower than the math score')
print(f'The maximum of any state\'s SAT english score is {diff_max:.2f}pts higher than the math score')
# Out:
# The average state has an SAT english score that is 8.61pts higher than the average math score
# The lowest of any state's SAT english score is 13.00pts lower than the math score
# The maximum of any state's SAT english score is 33.00pts higher than the math score

# %%
# SAT english scores are 8pts higher on average than math. Check which states manage to buck the trend,
# but not counting those with low participation rate
USA2019q[(USA2019q['math_sat'] >= USA2019q['english_sat']) & (USA2019q['participation_sat']>0.1)]
# Out:
#             state  participation_sat  english_sat  math_sat  total_sat  \
# 11         Hawaii               0.54          550       550       1100
# 21  Massachusetts               0.81          559       561       1120
# 30     New Jersey               0.82          544       545       1090
# 32       New York               0.79          531       533       1064
#
#     participation_act  total_act  median_income med_income_q
# 11               0.80       19.0          80212         high
# 21               0.21       25.5          79835         high
# 30               0.25       24.2          81740         high
# 32               0.22       24.5          67844         high

# %%
# there are only 4 such states where math scores are equal or higher than english,
# and they are all high-income states.
# Judging from this, the extra resources that student from rich states command 
# is reflected in higher math scores.

# next find low-income counties that manage to get good scores. By learning the keys
# to their schools' success we can reduce economic bias inherent to the College Board tests.

CA2019q[CA2019q['income_third'] == 'low'].sort_values(by=['ttl_act'], ascending=False).head()
# Out:
#       county_name  enroll  testtkr_sat  eng_bmark_sat  math_bmark_sat  \
# ccode
# 45         Shasta    2161          386          85.49           66.32
# 12       Humboldt    1342          300          83.33           59.00
# 23      Mendocino     988          217          80.18           54.38
# 4           Butte    2551          551          82.21           63.34
# 10         Fresno   14299         4070          65.45           39.78
#
#        ttl_bmark_sat  testtkr_act  read_act  eng_act  math_act  sci_act  \
# ccode
# 45             63.73        173.0      26.0     24.0      24.0     24.0
# 12             56.33        107.0      25.0     24.0      24.0     24.0
# 23             50.69         68.0      25.0     23.0      22.0     22.0
# 4              60.25        226.0      23.0     22.0      23.0     23.0
# 10             37.79       1805.0      21.0     20.0      20.0     20.0
#
#        ttl_bmark_act  ttl_act  hh_income income_third
# ccode
# ...

# %% [markdown]
# *Shasta county in is one of the lower-income counties in the state of California, yet the percentage of their students who attain college benchmark on their SATs and ACTs is more than 10% higher than the state average. This warrants further research beyond the scope of this notebook, to be included in the recommendation section.*

# %%
USA2019q[USA2019q['med_income_q'] == 'low'].sort_values(by='total_act', ascending=False).head()
# Out:
#             state  participation_sat  english_sat  math_sat  total_sat  \
# 19          Maine               0.99          512       502       1013
# 12          Idaho               1.00          505       488        993
# 14        Indiana               0.66          543       537       1080
# 48  West Virginia               0.99          483       460        943
# 25       Missouri               0.04          622       615       1236
#
#     participation_act  total_act  median_income med_income_q
# 19               0.06       24.3          55602          low
# 12               0.31       22.5          55583          low
# 14               0.29       22.5          55746          low
# 48               0.49       20.8          44097          low
# 25               0.82       20.8          54478          low

# %% [markdown]
# *On the list above, Maine can be disregarded due to its low ACT participation rate, which leaves us with Idaho and Indiana as the top two states with equal ACT score of 22.50 and high participation rates. We choose Indiana as its SAT score is substantially higher than Idaho (1080 vs 993). Further research  on specific policies that help Indiana score higher than its income will be  conducted. The conlusions will be listed in the recommendation section.*

# %% [markdown]
# ## A brief summary of EDA:
#
# ### a) even though it initially appears that SAT has less economic bias than SAT, that statement is easily disaproved: the difference is due to the different participation rates which in turn affect the average scores
# ### b) on a 'level playing field', in a state of California, where there are no state differences to account for, there is a clear trend towards better scores among wealthier counties
# ### c) wealthy background of a student mostly gets reflected in his or her SAT Math score. There is an improvement in english as well, but not nearly as pronounced.
# ### d) there are lower-income counties  and states where students nonethless achieve high average scores. Online and news reasearch has to be conducted, the results of which will be noted in the recommendation section.

# %% [markdown]
# **To-Do:** *Edit this cell with your findings on trends in the data (step 3 above).*

# %% [markdown]
# <a id = '4.0'><a/>
# ## 4.0 Data Visualization
# * [Back To Top](#Content)
#
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# ### Heatmap

# %%
plt.figure(figsize = (20,10))

ax1 = plt.subplot(121)
mask = np.zeros_like(USA2019q.corr())
mask[np.triu_indices_from(mask)] = True
colorshm = sns.diverging_palette(250, 15, as_cmap=True)
sns.heatmap(USA2019q.corr(), cmap= colorshm, mask = mask, annot=True, linewidths = 0.5, ax=ax1)
plt.title("USA", fontsize=20, color='purple', weight = 'heavy')

ax2 = plt.subplot(122)
mask = np.zeros_like(CA2019q.corr())
mask[np.triu_indices_from(mask)] = True
colorshm = sns.diverging_palette(250, 15, as_cmap=True)
sns.heatmap(CA2019q.corr(), cmap= colorshm, mask = mask, annot=True, linewidths = 0.5, ax=ax2,
            cbar=False)
plt.title("CALIFORNIA", fontsize=20, color='purple', weight = 'heavy')
plt.show()

# %% [markdown]
# - there are a few unusual boxes on the USA heatmap on the left.
#     - 1) ACT and SAT scores have substantial negative correlation (-0.42) with each other. One would typically expect the scores of these test to be positively correlated, as they measure the same thing - the scholastic aptitude.
#     - 2) the median income has a small but negative correlation with SAT scores (-0.17). Normally, the students with more resources are expected to score better.
#
#
# - both of these unexpected finding can be explained away by the other elements of the heatmap itself.
#     - Regarding the first point, SAT and ACT participations rates have a very high negative correlation (-0.87) with each other. And participation rates in general has a very negative correlation with scores on either test (also -0.87). That implies that in many states, one test has a high participation rate and low scores, while the other one is vice versa. In the end, the negative correlation between the two tests is a result of their participation rates, and this heatmap illustrates that point very clearly.
#     - As far as the second point regarding the negative correlation between income and SAT scores, the logic follows that of the first point: income has a fairly strong correlation with the SAT participation rates (0.41), which in turn has a negative correlation with SAT scores (-0.86). Therefore the high SAT participation rates in high income states are the cause of relatively low SAT scores there.

# %% [markdown]
# ### Histograms

# %%
# write a function to quickly create a histograms and places it on a subplot
def plot_hist(df, col, axis):
    """ plot_hist funcion takes in a dataframe, a column and a subplot axis
    to create simple histogram"""
    sns.histplot(data=df, x=col, ax=axis, color='darkolivegreen')
    axis.set(xlabel=None, ylabel=None)

# %%
# choose columns from USA2019q df to display
columns=['participation_sat', 'participation_act', 'total_sat', 'total_act']

# create 4s graph in 2x2 display
fig, ax = plt.subplots(2,2, figsize=(15,10))
fax = ax.ravel() # use ravel to make it easier to iterate through subplots
# next, loop through the columns and call the plot_hist function to display them
for i, col in enumerate(columns):
    plot_hist(USA2019q, col, fax[i])

# adjust the label display 
fig.text(0.301, 0.912, 'SAT', ha='center', fontsize = 15, color= 'deeppink', weight='bold')
fig.text(0.724, 0.912, 'ACT', ha='center', fontsize = 15, color= 'deeppink', weight='bold')
fax[0].set_ylabel("Participation rate", color='deeppink', fontsize=15, weight='heavy')
fax[2].set_ylabel("Test Scores", color='deeppink', fontsize=15, weight='heavy')
fig.suptitle("USA", fontsize = 30, color= 'maroon', weight='heavy')
# fax[2].set_xlabel("SAT", color='deeppink', fontsize=15, weight='heavy')
# fax[3].set_xlabel("ACT", color='deeppink', fontsize=15, weight='heavy')
# plt.show()

#repeat the process for the the other dataframe, CA2019q df. Use the same plot_hist function

columns=['math_bmark_sat', 'math_act', 'eng_bmark_sat', 'eng_act', 'ttl_bmark_sat', 'ttl_act']

fig, ax = plt.subplots(3,2, figsize=(15,15))
fax = ax.ravel()

for i, col in enumerate(columns):
    plot_hist(CA2019q, col, fax[i])
    
fax[0].set_ylabel("Math", color='deeppink', fontsize=15, weight='heavy')
fax[2].set_ylabel("English", color='deeppink', fontsize=15, weight='heavy')
fax[4].set_ylabel("Total", color='deeppink', fontsize=15, weight='heavy')
fax[4].set_xlabel("SAT", color='deeppink', fontsize=15, weight='heavy')
fax[5].set_xlabel("ACT", color='deeppink', fontsize=15, weight='heavy')
fig.suptitle("California", fontsize = 30, color= 'maroon', weight='heavy')

plt.show()

# %% [markdown]
# - the participation variables are 'opposite' of normally distributed.They have very observations around the mean, and both of their tails are fat. As mentioned before, that is the product of state requirements: some states mandate one of the test for all graduating seniors, thus causing that test's participation rate to be near 1.00 while the other test is then close to 0.
#
#
# -  test scores don't have a discernable distribution pattern. They are definitly not normal. Most of them, if anything, resemble a (somewhat messy) continuous uniform distribution.
#
#
# - we didnt' plot the income distribution histograms as that one has been well-reaserched in the past

# %% [markdown]
# > <font size = 3 color = "crimson"> Good work for writing a subplot function! Consider overlaying the histograms with vertical lines for mean and median. That does help with interpretation of skew.</font>

# %% [markdown]
# ### Boxplots

# %%
fig, axes = plt.subplots(2,2,figsize=(10,10))


# axes = axes.ravel()
sns.boxplot(data=CA2019q, x='income_third', y='ttl_bmark_act', ax=axes[0,0])
sns.boxplot(data=CA2019q, x='income_third', y='ttl_bmark_sat', ax=axes[0,1])
sns.boxplot(data=USA2019q, x='med_income_q', y='total_act', ax=axes[1,0])
sns.boxplot(data=USA2019q, x='med_income_q', y='total_sat', ax=axes[1,1])

fig.text(0.3, 0.032, 'ACT', ha='center', fontsize = 20, color= 'darksalmon', weight='bold')
fig.text(0.7, 0.032, 'SAT', ha='center', fontsize = 20, color= 'darksalmon', weight='bold')
fig.text(0.04, 0.7, 'California', va='center', rotation='vertical', fontsize = 20,
          color = 'darksalmon', weight = 'bold')
fig.text(0.04, 0.3, 'USA', va='center', rotation='vertical', fontsize = 20,
          color = 'darksalmon', weight = 'bold')
fig.suptitle("SAT/ACT by household income", fontsize = 20, color= 'maroon', weight='bold')
fig.text(0.3, 0.032, 'ACT', ha='center', fontsize = 20, color= 'darksalmon', weight='bold')
fig.text(0.7, 0.032, 'SAT', ha='center', fontsize = 20, color= 'darksalmon', weight='bold')
fig.text(0.3, 0.906, 'ACT', ha='center', fontsize = 20, color= 'darksalmon', weight='bold')
fig.text(0.7, 0.906, 'SAT', ha='center', fontsize = 20, color= 'darksalmon', weight='bold')
fig.text(0.04, 0.7, 'California', va='center', rotation='vertical', fontsize = 20,
          color = 'darksalmon', weight = 'bold')
fig.text(0.04, 0.3, 'USA', va='center', rotation='vertical', fontsize = 20,
          color = 'darksalmon', weight = 'bold')
fig.suptitle("SAT/ACT by household income", fontsize = 20, color= 'maroon', weight='bold')
axes[0,0].set(xlabel=None, ylabel=None)
axes[0,1].set(xlabel=None, ylabel=None)
axes[1,0].set(xlabel=None, ylabel=None)
axes[1,1].set(xlabel=None, ylabel=None)

plt.show()

# %% [markdown]
# > <font size = 3 color = "crimson"> Do review your inputs for the boxplots as the range of y values seem to be inconsistent. </font>

# %% [markdown]
# - the boxplots above show the range of test scores for different income ranks. As we have two tests (SAT and ACT) and two datasets (CA and USA) there are 4 charts.
#
# - a few outliers are observed, but they are all on the upside, and are the result of exceedingly high scores by the states that have very low participation rates. In that sense, these boxplots do not tell as anything we don't already know
#
# - 3 out of 4 follow a predictable pattern - the scores rise together with income rank. The fourth chart in the bottom right of the figure (SAT for the entire USA) digresses from the pattern, and shows lower scores for high-income students. The reason for that have been discussed in the Heatmap section.

# %% [markdown]
# ### Distribution plot of scores at different income levels

# %%
fix, [[ax1, ax2], [ax3, ax4]] = plt.subplots(2,2, figsize = (10,10))
sns.regplot(data=CA2019q, x='ttl_bmark_sat', y='ttl_bmark_act', ax=ax1)
sns.regplot(data=CA2019q, x='ttl_bmark_sat', y='hh_income', ax=ax2)
ax2.yaxis.tick_right()
sns.regplot(data=CA2019q, x='sci_act', y='math_act', ax=ax3)
sns.regplot(data=CA2019q, x='sci_act', y='eng_act', ax=ax4)
plt.show()

# %% [markdown]
# ** A few new relationships were explored in these charts:**
#
# - the relationship between ACT and SAT scores among Californian counties is strong and positive
#
# - the relationship between the county income and SAT scores is also positive, but exibits more variance (wider confidence intervals) at high end of the scores spectrum. That means that some poorer counties managed to score well (we noted the example of Shasta county during EDA)
#
# - ACT science scores with graphed against math and english, but nothing unuasal was noted

# %% [markdown]
# ### Extra plots

# %%
# count of scores split by income rank
sns.displot(data=CA2019q, x='ttl_bmark_sat', hue='income_third', col='income_third')
sns.displot(data=CA2019q, x='ttl_bmark_act', hue='income_third', col='income_third')

# %% [markdown]
# - when we look at data at the county level in the state of California, with uniform participation rules all across the state, (unlike what we had between the US states), the scores follow the expected pattern. On the left (in blue) the lower-income student's scores are bunched up on the left side of the x-axis - towards the lower end of the spectrum, while the green scores on the right for the wealthier students tend to peak on the right side of the x-axis (the higher end of the spectrum). The middle-income student, as expected, exhibit close to a normal distribution, peaking around the mean.

# %% [markdown]
# ###  difference between the math and english scores plotted versus the overall score

# %%
fig = plt.figure(figsize = (9,6))
chart = sns.scatterplot(data=USA2019q, x=(USA2019q['math_sat']-USA2019q['english_sat']), y=USA2019q['total_sat'],
                hue='med_income_q')
leg = chart.axes.get_legend()
leg.set_title('Income Rank')
plt.title('SAT\nMath - English vs Math + English', size=14, color='maroon', y=1.03)
plt.xlabel('Math - English SAT',size=12, color='darksalmon', weight='heavy')
plt.ylabel('Math + English (Total) SAT score',size=12, color='darksalmon', weight='heavy')
plt.show()
# fig.savefig('../images/scatter1')

# %% [markdown]
# Two trends can be gleaned from the above plot:
#
# - 1) there is definitely a positive correlation between the states with better scores on one side and the states who do better in math than english on the other
# - 2) the states in the top right corner that outperform in math are virutally all high-income states
# - 3) this implies that the extra resources that high-income states have at their disposal translate more into improvements in their math, rather than in their english skills

# %% [markdown]
# ### kernel density plot showing inconsistent SAT participation rates among states of different income rank

# %%
fig = plt.figure(figsize=(8,6))

chart = sns.kdeplot(data=USA2019q, x='participation_sat', hue='med_income_q',legend=False)

plt.title("SAT participation rates by state income rank", size=14, color='maroon',y=1.03)
plt.xlabel('Density', size=12, color='darksalmon', weight='heavy')
plt.ylabel('SAT participation rate', size=12, color='darksalmon', weight='heavy')
plt.legend(title='Income Rank', loc='upper right', labels=['High', 'Middle', 'Low'])

plt.show()
# fig.savefig('../images/kdeplot')

# %% [markdown]
# - the kernel density plot clearly show that the high-income states (green line) have very high SAT participation rates

# %% [markdown]
# ### another scatterplot with hue for income rank, with the emphasis on academic out-performers in the low-income world.

# %%
fig, (ax1, ax2) = plt.subplots(1,2,figsize=(13,6))
chart = sns.scatterplot(data=CA2019q[CA2019q['county_name'] == 'Shasta'], x='ttl_bmark_sat', y='ttl_bmark_act',
                color= '#2b7bba', s=175, ax=ax1)
sns.scatterplot(data=CA2019q, x='ttl_bmark_sat', y='ttl_bmark_act', hue='income_third',ax=ax1)
leg = chart.axes.get_legend()
leg.set_title('Income Rank')
ax1.set_title('Shasta county - California', size=14, color='maroon')
ax1.set_xlabel('SAT score by county',size=12, color='darksalmon', weight='heavy')
ax1.set_ylabel('ACT score by county',size=12, color='darksalmon', weight='heavy')
ax1.arrow(51,75.5,8.3,0, width=0.5, head_width=2, color='fuchsia')

chart2 = sns.scatterplot(data=USA2019q[USA2019q['state'] == 'Indiana'], x='total_sat', y='total_act',
                color= '#2b7bba', s=175, ax=ax2)
sns.scatterplot(data=USA2019q[(USA2019q['participation_sat'] > 0.1) & (USA2019q['participation_act'] > 0.1)],
                x='total_sat', y='total_act', hue='med_income_q',ax=ax2)
leg = chart2.axes.get_legend()
leg.set_title('Income Rank')
ax2.set_title('The State of Indiana', size=14, color='maroon')
plt.xlabel('SAT score by state',size=12, color='darksalmon', weight='heavy')
plt.ylabel('ACT score by state',size=12, color='darksalmon', weight='heavy')
ax2.arrow(1140,22.5,-39,0, width=0.07, head_width=0.3, color='fuchsia', head_length=13.5)
plt.suptitle('Low income but high achievers', size=26, color='maroon',y=1.03)
plt.show()
# fig.savefig('../images/scatter2')

# %% [markdown]
# *the charts above clearly show that among low-income counties and states (blue dots), the two outsize blue dots stand out in terms of overachieving their academic potential. Actually, they are both among top-performing schools overall in terms of scoring high on both SAT and ACTs, and not just among their low-income peers*

# %% [markdown]
# <a id = '5.0'><a/>
# ## Conclusions and Recommendations
# * [Back To Top](#Content)

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# **Conclusions:**
#
# - SAT is by no means better than ACT in terms of avoiding economic bias. What looks like an advantage for SAT in that respect, was shown by this analysis to be a mere product of different state policies towards mandatory testing, rather than some inherent lack of economic bias of SAT.
#
# - unfortunately, that does not mean that there is no economic bias in ACT and SAT. Rather, the conclusion is that the bias is still here, and still strong. This analysis supports that claim by focusing on one individual state - California -and delving deep into its county-by-county data, which show a clear pattern of economic bias.
#
# - in national SAT data, the math scores difference between states from different sides of the income spectrum is more pronounced then the english difference. This suggests that focusing more on math in lower-income states would be a more cost-effective way to level the playing field.
#
# **Recommendations:**
#
# -  rather than throwing more money at the problem of underperforming schools from poorer districts, we envision a way forward whereby outperforming schools from low-income areas are identified on a regular basis through data analysis. Following that, we  will endeavor to learn the programs they had put in place that helped them achieve such success. Finally, we proceed to advise and inform schools around the nation to implement those same policies which would reduce the economic bias in testing and "take some heat off" ACT Inc, politically speaking. A couple of examples of school and state policies from 2019 data that bore academic fruits are:
#
# -
#    - in Shasta County, the top performing low-income county in California, Central Valley High School has CollegeVine program in place which helps students transition from high-school to college and its way of studying. It combines the best of both worlds - a safe and familiar high-school environment together with college preparation and coursework. Aside from sharpening their academic skills, the students also attain confidence, maturity and a realistic outlook. Those are the intangible skills that can help a young person take their studies more seriously, thereby helping them score higher on the College Board exams without the benefit of money or extra tuition. More here:   https://www.redding.com/story/news/2021/11/10/central-valley-high-school-dual-enrollment-college-credit-university-courses/6358940001/
#
#
# -
#     - similar to throwing more money at the problem, putting more academic pressure on students is unlikely to lead to any long-term improvement in test scores, as the students are under enough pressure already. That's why in 2018 the State of Indiana adopted a new program developed by University of Chicago researchers called "5 Essentials" to improve their schools. The program grades schools based on non-academic criteria such as leadership, collaboration and family support and the program has been proven both successful and popular when piloted in Chicago a few years ago. Indiana performed quite well in 2019 for a state with "low" income rank. Follow up research on this in a few years will be needed. More here:
#     https://in.chalkbeat.org/2018/9/4/21105695/indiana-officials-didn-t-have-to-go-far-to-find-a-new-model-for-improving-schools

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!

# %% [markdown]
# > <font size = 3 color = "crimson"> Do remove the To-Do prompts from your notebook </font>
